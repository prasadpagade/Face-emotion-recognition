# %% [markdown]
# # Data Wrangling using Python and MongoDB
#
# ###### by Prasad Pagade
#
#
# ## Project Details (Wrangle OpenStreetMap Data):
#
# 1. Location: Santa Clara, CA, USA
#
# 2. Reason for choosing the location: I live in the **Bay Area** and I am very passionate about the city **Santa Clara** in which I reside. The Santa Clara OSM file was 58MB which met the minimum file size of 50MB. Hence, I chose the Santa Clara dataset from MapZen.
#
# 3. Dataset: [Santa Clara, CA](https://1drv.ms/u/s!Alalhc0dZibggwbIg32Q8crZoDmr)
#
# ### Objective
# You will choose any area of the world in https://www.openstreetmap.org and use data munging techniques, such as assessing the quality of the data for validity, accuracy, completeness, consistency and uniformity, to clean the OpenStreetMap data for a part of the world that you care about. Finally, you will choose either MongoDB or SQL as the data schema to complete your project.
#
# #### References:
# 1. Udacity "Data Wrangling with MongoDB" - Lesson 6
#
# 2. [MongoDB documentation](https://docs.mongodb.com/manual/tutorial/install-mongodb-enterprise-on-windows/?_ga=1.121437642.337829721.1481582931)
#
# 3. **Any more that are necessary here ********************************8
#
# #### Table of content:
#
# 1. Data Audit
# 2. Problem encountered
# 3. Data Cleaning
# 4. Insights through MongoDB
# 5. Conclusion

# %% [markdown]
# ##  1. Data Audit

# %%
# Import all the libraries

import xml.etree.cElementTree as ET
import pprint
import re
import codecs
import json
import collections
import pymongo
from pymongo import MongoClient

# %%
import os
"""
datadir = "data"
datafile = "San_Jose_city.osm"
sj_data = os.path.join(datadir, datafile)
#sj_data.replace("\\","\")
sj_data1 = "San_Jose_city.osm"
"""
## test Santa Clara data
sc_data = "SantaClara_county.osm"

# %%
sc_data
# Out:
# 'SantaClara_county.osm'

# %%
os.path.exists(sc_data)
# Out:
# True

# %%
# now lets parse through the OSM file using an element tree parser and explore the tags on a highlevel.

# We use the count_tags method used in the exercise in Lesson 6 - MongoDB

def count_tags(filename):
    tags = {}
    print filename
    for event,elem in ET.iterparse(filename):
        if elem.tag in tags:
            tags[elem.tag] += 1
        else:
            tags[elem.tag] = 1
    return tags

# %%
sc_tags = count_tags(sc_data)
sc_tags
# Out:
# SantaClara_county.osm
# {'bounds': 1,
#  'member': 4769,
#  'nd': 312292,
#  'node': 263052,
#  'osm': 1,
#  'relation': 484,
#  'tag': 132884,
#  'way': 39342}

# %%
print 'The original OSM file is {} MB'.format(os.path.getsize(sc_data)/1.0e6)
# Out:
# The original OSM file is 58.944542 MB

# %%
# Print a sample of the file. Here I am printing the first 100 elements

OSM_FILE = sc_data  # Replace this with your osm file
SAMPLE_FILE = "sample.osm"

k = 100 # Parameter: print the first k elements (or every kth element)

def get_element(osm_file, tags=('node', 'way', 'relation')):
    """Yield element if it is the right type of tag

    Reference:
    http://stackoverflow.com/questions/3095434/inserting-newlines-in-xml-file-generated-via-xml-etree-elementtree-in-python
    """
    context = iter(ET.iterparse(osm_file, events=('start', 'end')))
    _, root = next(context)
    for event, elem in context:
        if event == 'end' and elem.tag in tags:
            yield elem
            root.clear()


# print the first  k top level elements
for i, element in enumerate(get_element(OSM_FILE)):
    if i <= k:
        print ET.tostring(element)
'''
# or print every  kth top level elements
for i, element in enumerate(get_element(OSM_FILE)):
    if i % k == 0:
        print ET.tostring(element)
'''
# Also writing the sample file to view it in Sublime text
with open(SAMPLE_FILE, 'wb') as output:
    output.write('<?xml version="1.0" encoding="UTF-8"?>\n')
    output.write('<osm>\n  ')

    # Write every kth top level element
    for i, element in enumerate(get_element(OSM_FILE)):
        if i % k == 0:
            output.write(ET.tostring(element, encoding='utf-8'))

    output.write('</osm>')
# Out:
# <node changeset="16866449" id="26027690" lat="37.3531613" lon="-122.0140663" timestamp="2013-07-07T21:29:38Z" uid="318696" user="n76" version="21">
# 		<tag k="highway" v="traffic_signals" />
# 	</node>
#
# <node changeset="18300806" id="26027694" lat="37.3527232" lon="-122.0129194" timestamp="2013-10-11T16:32:56Z" uid="1376118" user="ChrisZontine" version="20" />
#
# <node changeset="9044962" id="26027695" lat="37.3522694" lon="-122.0103794" timestamp="2011-08-17T08:21:29Z" uid="14293" user="KindredCoda" version="19" />
#
# <node changeset="9044962" id="26027697" lat="37.3525316" lon="-122.0122684" timestamp="2011-08-17T08:21:29Z" uid="14293" user="KindredCoda" version="19" />
#
# <node changeset="9044962" id="26027704" lat="37.3523199" lon="-122.0110571" timestamp="2011-08-17T08:21:29Z" uid="14293" user="KindredCoda" version="19" />
#
# <node changeset="20818043" id="26027965" lat="37.3666158" lon="-122.013768" timestamp="2014-02-27T22:01:31Z" uid="318696" user="n76" version="8" />
#
# <node changeset="4949992" id="26027968" lat="37.3729016" lon="-122.013795" timestamp="2010-06-09T22:21:00Z" uid="296587" user="bmhr" version="6" />
#
# <node changeset="7124511" id="26027969" lat="37.3745913" lon="-122.0137249" timestamp="2011-01-29T17:07:13Z" uid="201724" user="mk408" version="12" />
#
# <node changeset="363058" id="26027971" lat="37.3758901" lon="-122.0136194" timestamp="2009-02-11T08:10:12Z" uid="93800" user="Alan Vogt" version="6" />
#
# <node changeset="7124511" id="26027973" lat="37.3796307" lon="-122.0123887" timestamp="2011-01-29T17:08:28Z" uid="201724" user="mk408" version="7" />
#
# <node changeset="7124511" id="26027974" lat="37.3800797" lon="-122.0121596" timestamp="2011-01-29T17:08:30Z" uid="201724" user="mk408" version="8" />
#
# <node changeset="7124511" id="26027975" lat="37.3804127" lon="-122.0119681" timestamp="2011-01-29T17:08:34Z" uid="201724" user="mk408" version="8" />
#
# <node changeset="363058" id="26027976" lat="37.381184" lon="-122.011833" timestamp="2009-02-11T08:10:13Z" uid="93800" user="Alan Vogt" version="6" />
#
# <node changeset="24359673" id="26027977" lat="37.3830944" lon="-122.0129908" timestamp="2014-07-25T22:53:53Z" uid="590608" user="robertstack" version="7" />
#
# <node changeset="24359673" id="26027978" lat="37.3833641" lon="-122.0133298" timestamp="2014-07-25T22:53:53Z" uid="590608" user="robertstack" version="7" />
#
# <node changeset="24359673" id="26027979" lat="37.3835778" lon="-122.0137162" timestamp="2014-07-25T22:53:53Z" uid="590608" user="robertstack" version="6" />
#
# <node changeset="36943114" id="26029047" lat="37.3980005" lon="-122.0119465" timestamp="2016-02-01T18:48:08Z" uid="2748195" user="karitotp" version="7" />
#
# <node changeset="16866449" id="26029630" lat="37.3529671" lon="-122.0140679" timestamp="2013-07-07T21:29:38Z" uid="318696" user="n76" version="25">
# 		<tag k="highway" v="traffic_signals" />
# 	</node>
#
# <node changeset="9044962" id="26029631" lat="37.3525659" lon="-122.0130354" timestamp="2011-08-17T07:53:29Z" uid="14293" user="KindredCoda" version="21" />
#
# <node changeset="31215083" id="26029632" lat="37.3523544" lon="-122.0122361" timestamp="2015-05-17T00:01:56Z" uid="74705" user="Bike Mapper" version="25" />
#
# <node changeset="9044962" id="26029633" lat="37.3522134" lon="-122.0113415" timestamp="2011-08-17T08:21:29Z" uid="14293" user="KindredCoda" version="22" />
#
# <node changeset="23082041" id="26031429" lat="37.3807647" lon="-121.9599129" timestamp="2014-06-22T14:37:20Z" uid="1660455" user="juergenb22" version="20" />
#
# <node changeset="36939372" id="26031430" lat="37.3834281" lon="-121.9683921" timestamp="2016-02-01T15:45:18Z" uid="2748195" user="karitotp" version="26" />
#
# <node changeset="12135372" id="26031433" lat="37.3901447" lon="-121.9921189" timestamp="2012-07-06T22:08:20Z" uid="169004" user="oldtopos" version="28">
# 		<tag k="ref" v="394" />
# 		<tag k="exit_to" v="Lawrence Expressway" />
# 		<tag k="highway" v="motorway_junction" />
# 	</node>
#
# <node changeset="13575017" id="26117833" lat="37.3752444" lon="-122.0136975" timestamp="2012-10-21T02:40:09Z" uid="11776" user="Marcus Wolschon" version="11">
# 		<tag k="highway" v="traffic_signals" />
# 		<tag k="source:highway" v="survey" />
# 	</node>
#
# <node changeset="28807896" id="26149266" lat="37.3514258" lon="-122.0142844" timestamp="2015-02-12T20:35:29Z" uid="318696" user="n76" version="7" />
#
# <node changeset="793775" id="26149269" lat="37.3373924" lon="-122.0141803" timestamp="2008-11-25T08:39:05Z" uid="54598" user="adbrown" version="4" />
#
# <node changeset="31334304" id="26149271" lat="37.3277617" lon="-122.0142251" timestamp="2015-05-21T06:17:12Z" uid="202256" user="Telecas" version="7" />
#
# <node changeset="31334304" id="26149285" lat="37.3286255" lon="-122.013519" timestamp="2015-05-21T06:17:12Z" uid="202256" user="Telecas" version="4" />
#
# <node changeset="31334304" id="26149286" lat="37.328641" lon="-122.0123593" timestamp="2015-05-21T06:17:12Z" uid="202256" user="Telecas" version="3" />
#
# <node changeset="441629" id="26149287" lat="37.3279039" lon="-122.0134944" timestamp="2007-11-08T19:23:11Z" uid="6157" user="raf" version="3">
# 		<tag k="created_by" v="JOSM" />
# 	</node>
#
# <node changeset="31334304" id="26149288" lat="37.3276935" lon="-122.0139891" timestamp="2015-05-21T06:17:12Z" uid="202256" user="Telecas" version="6" />
#
# <node changeset="24413610" id="26240930" lat="37.3781276" lon="-121.9483055" timestamp="2014-07-29T01:42:47Z" uid="28775" user="StellanL" version="21" />
#
# <node changeset="20468678" id="26250370" lat="37.3688113" lon="-122.013612" timestamp="2014-02-09T16:59:41Z" uid="169004" user="oldtopos" version="6" />
#
# <node changeset="2730399" id="26270058" lat="37.3835449" lon="-122.0142272" timestamp="2009-10-03T23:32:45Z" uid="81024" user="wallclimber21" version="4" />
#
# <node changeset="4144270" id="26374405" lat="37.3551116" lon="-121.9455568" timestamp="2010-03-16T15:49:45Z" uid="201724" user="mk408" version="21" />
#
# <node changeset="793775" id="26374406" lat="37.3557034" lon="-121.9433917" timestamp="2008-11-25T07:07:19Z" uid="54598" user="adbrown" version="19" />
#
# <node changeset="32109704" id="26374407" lat="37.3530879" lon="-121.9383309" timestamp="2015-06-21T05:07:50Z" uid="33757" user="Minh Nguyen" version="33">
# 		<tag k="highway" v="traffic_signals" />
# 	</node>
#
# <node changeset="32109704" id="26374408" lat="37.3519373" lon="-121.9370983" timestamp="2015-06-21T05:07:49Z" uid="33757" user="Minh Nguyen" version="26">
# 		<tag k="highway" v="crossing" />
# 		<tag k="crossing" v="zebra" />
# 	</node>
#
# <node changeset="22358519" id="26374415" lat="37.3553117" lon="-121.9451537" timestamp="2014-05-15T19:03:05Z" uid="595221" user="matthieun" version="21" />
#
# <node changeset="19944833" id="26374416" lat="37.3526838" lon="-121.9518915" timestamp="2014-01-11T23:24:45Z" uid="318696" user="n76" version="18" />
#
# <node changeset="32400887" id="26374418" lat="37.3555385" lon="-121.9442251" timestamp="2015-07-03T23:30:10Z" uid="33757" user="Minh Nguyen" version="15" />
#
# <node changeset="32904574" id="26374419" lat="37.355419" lon="-121.9430954" timestamp="2015-07-27T09:12:43Z" uid="33757" user="Minh Nguyen" version="15" />
#
# <node changeset="32400887" id="26374420" lat="37.3530397" lon="-121.9385683" timestamp="2015-07-03T23:30:10Z" uid="33757" user="Minh Nguyen" version="26">
# 		<tag k="highway" v="traffic_signals" />
# 	</node>
#
# <node changeset="32109704" id="26374421" lat="37.3521025" lon="-121.9374694" timestamp="2015-06-21T05:07:49Z" uid="33757" user="Minh Nguyen" version="17">
# 		<tag k="highway" v="crossing" />
# 		<tag k="crossing" v="zebra" />
# 	</node>
#
# <node changeset="8422366" id="26393311" lat="37.426758" lon="-121.921713" timestamp="2011-06-13T06:58:07Z" uid="14293" user="KindredCoda" version="6" />
#
# <node changeset="8241098" id="26404628" lat="37.3172777" lon="-121.9347149" timestamp="2011-05-25T02:48:32Z" uid="14293" user="KindredCoda" version="47" />
#
# <node changeset="8231395" id="26497360" lat="37.3282903" lon="-122.0142766" timestamp="2011-05-23T23:51:48Z" uid="14293" user="KindredCoda" version="11" />
#
# <node changeset="36941154" id="26506775" lat="37.3744614" lon="-121.9510007" timestamp="2016-02-01T17:15:32Z" uid="2748195" user="karitotp" version="8" />
#
# <node changeset="36938880" id="26506776" lat="37.3746186" lon="-121.9753002" timestamp="2016-02-01T15:21:29Z" uid="2748195" user="karitotp" version="9" />
#
# <node changeset="794494" id="26506778" lat="37.3773825" lon="-121.9799316" timestamp="2009-03-12T01:10:07Z" uid="100744" user="fennecfoxen" version="11" />
#
# <node changeset="13757040" id="26506779" lat="37.3776145" lon="-122.0019069" timestamp="2012-11-05T06:33:45Z" uid="47892" user="richlv" version="8" />
#
# <node changeset="22783625" id="26506781" lat="37.3766569" lon="-122.006121" timestamp="2014-06-06T21:26:05Z" uid="771165" user="LXT" version="6" />
#
# <node changeset="28601952" id="26506782" lat="37.3766796" lon="-122.0070542" timestamp="2015-02-04T00:01:01Z" uid="595221" user="matthieun" version="8" />
#
# <node changeset="28601952" id="26506784" lat="37.3770987" lon="-122.0089047" timestamp="2015-02-04T00:01:01Z" uid="595221" user="matthieun" version="9" />
#
# <node changeset="7124511" id="26506786" lat="37.3785814" lon="-122.012721" timestamp="2011-01-29T17:08:29Z" uid="201724" user="mk408" version="11">
# 		<tag k="highway" v="traffic_signals" />
# 	</node>
#
# <node changeset="794494" id="26506793" lat="37.3778414" lon="-121.9813732" timestamp="2009-03-12T01:12:03Z" uid="100744" user="fennecfoxen" version="14" />
#
# <node changeset="39276833" id="26506797" lat="37.3744227" lon="-121.9590346" timestamp="2016-05-12T20:01:09Z" uid="1829683" user="Luis36995" version="8" />
#
# <node changeset="8233100" id="26506823" lat="37.3189023" lon="-121.9913763" timestamp="2011-05-24T08:32:22Z" uid="14293" user="KindredCoda" version="32" />
#
# <node changeset="36938880" id="26511937" lat="37.375421" lon="-121.9769681" timestamp="2016-02-01T15:21:29Z" uid="2748195" user="karitotp" version="11" />
#
# <node changeset="20817845" id="32331543" lat="37.4028735" lon="-122.0102919" timestamp="2014-02-27T21:51:07Z" uid="318696" user="n76" version="30" />
#
# <node changeset="29670773" id="32331544" lat="37.4030294" lon="-122.0102364" timestamp="2015-03-23T05:32:20Z" uid="2763448" user="Daniel_Caldwell" version="26" />
#
# <node changeset="6776772" id="32331545" lat="37.4053195" lon="-122.009538" timestamp="2010-12-27T12:02:26Z" uid="14293" user="KindredCoda" version="6" />
#
# <node changeset="865564" id="32351568" lat="37.4034494" lon="-121.9995614" timestamp="2009-03-28T08:13:47Z" uid="28775" user="StellanL" version="24" />
#
# <node changeset="865564" id="32351574" lat="37.4032474" lon="-122.0052385" timestamp="2009-03-28T08:13:47Z" uid="28775" user="StellanL" version="18" />
#
# <node changeset="4090955" id="32351575" lat="37.4024513" lon="-122.0075911" timestamp="2010-03-10T16:34:53Z" uid="201724" user="mk408" version="19" />
#
# <node changeset="28196530" id="32351576" lat="37.4064644" lon="-122.0095454" timestamp="2015-01-16T21:38:50Z" uid="28775" user="StellanL" version="13" />
#
# <node changeset="39147451" id="32351577" lat="37.4077414" lon="-122.0101073" timestamp="2016-05-06T16:10:16Z" uid="2226712" user="dannykath" version="10" />
#
# <node changeset="20817845" id="32351578" lat="37.4087599" lon="-122.0109726" timestamp="2014-02-27T21:51:07Z" uid="318696" user="n76" version="25" />
#
# <node changeset="20275150" id="32351579" lat="37.4085051" lon="-122.01106" timestamp="2014-01-29T23:31:49Z" uid="318696" user="n76" version="10" />
#
# <node changeset="25711289" id="32351580" lat="37.4073636" lon="-122.0114517" timestamp="2014-09-27T18:27:11Z" uid="318696" user="n76" version="4" />
#
# <node changeset="36943776" id="32351595" lat="37.4060422" lon="-122.01349" timestamp="2016-02-01T19:18:46Z" uid="2748195" user="karitotp" version="5" />
#
# <node changeset="20303686" id="32351596" lat="37.4025145" lon="-122.0068589" timestamp="2014-01-31T17:35:21Z" uid="318696" user="n76" version="20" />
#
# <node changeset="865564" id="32351599" lat="37.4033405" lon="-122.0044299" timestamp="2009-03-28T08:13:47Z" uid="28775" user="StellanL" version="18" />
#
# <node changeset="8943068" id="32790334" lat="37.4228621" lon="-121.9257204" timestamp="2011-08-07T00:40:05Z" uid="207745" user="NE2" version="6" />
#
# <node changeset="6784016" id="32790335" lat="37.4225718" lon="-121.9286509" timestamp="2010-12-28T01:07:33Z" uid="14293" user="KindredCoda" version="4" />
#
# <node changeset="6784016" id="32790337" lat="37.4221458" lon="-121.9318293" timestamp="2010-12-28T01:18:07Z" uid="14293" user="KindredCoda" version="4" />
#
# <node changeset="4656002" id="32790340" lat="37.4200088" lon="-121.9413075" timestamp="2010-05-10T05:36:21Z" uid="14293" user="KindredCoda" version="5" />
#
# <node changeset="4656002" id="32790341" lat="37.4196381" lon="-121.9429383" timestamp="2010-05-10T05:36:22Z" uid="14293" user="KindredCoda" version="4" />
#
# <node changeset="4635988" id="32790342" lat="37.4194336" lon="-121.9446575" timestamp="2010-05-08T06:39:35Z" uid="14293" user="KindredCoda" version="4" />
#
# <node changeset="4635988" id="32790344" lat="37.4194421" lon="-121.9525163" timestamp="2010-05-08T06:39:06Z" uid="14293" user="KindredCoda" version="4" />
#
# <node changeset="4635988" id="32790345" lat="37.419408" lon="-121.9579639" timestamp="2010-05-08T06:38:24Z" uid="14293" user="KindredCoda" version="3" />
#
# <node changeset="4635988" id="32790346" lat="37.4192696" lon="-121.9606193" timestamp="2010-05-08T06:37:57Z" uid="14293" user="KindredCoda" version="3" />
#
# <node changeset="8233100" id="32817446" lat="37.3186125" lon="-121.990474" timestamp="2011-05-24T08:32:22Z" uid="14293" user="KindredCoda" version="34" />
#
# <node changeset="8233100" id="32817447" lat="37.3182335" lon="-121.9885677" timestamp="2011-05-24T08:32:22Z" uid="14293" user="KindredCoda" version="33" />
#
# <node changeset="8233100" id="32817448" lat="37.3181713" lon="-121.9870925" timestamp="2011-05-24T08:32:22Z" uid="14293" user="KindredCoda" version="33" />
#
# <node changeset="8233296" id="32817449" lat="37.3182056" lon="-121.9810551" timestamp="2011-05-24T09:00:12Z" uid="14293" user="KindredCoda" version="33" />
#
# <node changeset="8233296" id="32817450" lat="37.3181601" lon="-121.9790801" timestamp="2011-05-24T09:00:12Z" uid="14293" user="KindredCoda" version="34" />
#
# <node changeset="8233296" id="32817451" lat="37.3179476" lon="-121.9771151" timestamp="2011-05-24T09:00:12Z" uid="14293" user="KindredCoda" version="33" />
#
# <node changeset="8233296" id="32817452" lat="37.3171176" lon="-121.9743554" timestamp="2011-05-24T09:00:12Z" uid="14293" user="KindredCoda" version="32" />
#
# <node changeset="8233296" id="32817453" lat="37.3166276" lon="-121.9724871" timestamp="2011-05-24T09:00:12Z" uid="14293" user="KindredCoda" version="32" />
#
# <node changeset="8233296" id="32817454" lat="37.3164102" lon="-121.9695545" timestamp="2011-05-24T09:00:12Z" uid="14293" user="KindredCoda" version="33" />
#
# <node changeset="8232841" id="32817455" lat="37.3165294" lon="-121.9657714" timestamp="2011-05-24T07:55:03Z" uid="14293" user="KindredCoda" version="32" />
#
# <node changeset="8232841" id="32817457" lat="37.3165116" lon="-121.9582873" timestamp="2011-05-24T07:55:03Z" uid="14293" user="KindredCoda" version="30" />
#
# <node changeset="10826343" id="32817458" lat="37.3167178" lon="-121.9516384" timestamp="2012-02-29T10:13:05Z" uid="14293" user="KindredCoda" version="48" />
#
# <node changeset="21368423" id="32875800" lat="37.3496042" lon="-121.9961802" timestamp="2014-03-28T16:19:54Z" uid="595221" user="matthieun" version="7" />
#
# <node changeset="794494" id="32875801" lat="37.3477486" lon="-121.9959842" timestamp="2009-03-12T01:13:33Z" uid="100744" user="fennecfoxen" version="3" />
#
# <node changeset="30174277" id="32875811" lat="37.3229482" lon="-121.9964556" timestamp="2015-04-12T21:42:45Z" uid="318696" user="n76" version="13" />
#
# <node changeset="19963761" id="32875813" lat="37.3229892" lon="-121.9925257" timestamp="2014-01-13T00:13:18Z" uid="318696" user="n76" version="10" />
#
# <node changeset="21630577" id="32875815" lat="37.3524714" lon="-121.9958616" timestamp="2014-04-11T17:02:22Z" uid="318696" user="n76" version="21" />
# <node changeset="21630577" id="32875818" lat="37.3522114" lon="-121.995837" timestamp="2014-04-11T17:02:22Z" uid="318696" user="n76" version="26" />

# %% [markdown]
# So, I wanted to oversee the structure of the OSM file. I sampled the first 100 elements and exported them to "SAMPLE_FILE.osm". Found out that the OSM file is structured into Nodes, Ways and Tags.

# %% [markdown]
# We want to explore the data a bit more.Before we process the data and add it into the database, we should check the
# "k" value for each **"tag"** and see if there are any potential problems.
#
# The lesson from "Case Study" provided us with 3 regular expressions to check for certain patterns in the tags. We would like to change the data model and expand the "addr:street" type of keys to a dictionary like this:
# {"address": {"street": "Some value"}}
#
# So, we have to see if we have such tags, and if we have any tags with
# problematic characters.
#
# The function 'key_type', such that we have a count of each of four tag categories in a dictionary:
#
# 1.  "lower", for tags that contain only lowercase letters and are valid,
# 2.  "lower_colon", for otherwise valid tags with a colon in their names,
# 3.  "problemchars", for tags with problematic characters, and
# 4.  "other", for other tags that do not fall into the other three categories.

# %%
import re

lower = re.compile(r'^([a-z]|_)*$')
lower_colon = re.compile(r'^([a-z]|_)*:([a-z]|_)*$')
problemchars = re.compile(r'[=\+/&<>;\'"\?%#$@\,\. \t\r\n]')

def key_type(element, keys):
    if element.tag == 'tag':
        for val in element.iter('tag'):
            k = element.get('k')
            #search for the "lower"
            if lower.search(k):
                keys['lower'] += 1
            elif lower_colon.search(k):
                keys['lower_colon'] += 1
            elif problemchars.search(k):
                keys['problemchars'] += 1
            else:
                keys['other'] += 1
    return keys

def process_map(filename):
    keys = {"lower": 0, "lower_colon": 0, "problemchars": 0, "other": 0}
    for _, element in ET.iterparse(filename):
        keys = key_type(element, keys)

    return keys

# %%
sc_tag_category = process_map(sc_data)

pprint.pprint(sc_tag_category)
# Out:
# {'lower': 83405, 'lower_colon': 45994, 'other': 3485, 'problemchars': 0}

# %% [markdown]
# Now, let us explore the users

# %%
# this function will tell us how many unique users have already contributed to the map data

def get_user(element):
    if element.get('uid'):
        uid = element.attrib['uid']
        return uid
    else:
        return None
    
    

def process_map(filename):
    users = set()
    for _, element in ET.iterparse(filename):
        if get_user(element):
            users.add(get_user(element))

    return users

sc_users = process_map(sc_data)
len(sc_users)
# Out:
# 547

# %% [markdown]
# So **547** users have contributed to the map data. That's way less than what I had expected.

# %% [markdown]
# # 2. Problem encountered

# %% [markdown]
# Next we audit the street names to see if they are in their expected format. If not, then we may have to map a way to rename the street names to its expected values.

# %% [markdown]
# ## 2.1 Street Names

# %%
from collections import defaultdict

street_type_re = re.compile(r'\b\S+\.?$', re.IGNORECASE)

expected = ["Avenue", "Boulevard", "Commons", "Court", "Drive", "Lane", "Parkway", 
                         "Place", "Road", "Square", "Street", "Trail"]
# we will be updating the mapping dictionary from the audit iterations
mapping = {'Ave'  : 'Avenue',
           'Blvd' : 'Boulevard',
           'Dr'   : 'Drive',
           'Ln'   : 'Lane',
           'Pkwy' : 'Parkway',
           'Rd'   : 'Road',
           'Rd.'   : 'Road',
           'St'   : 'Street',
           'street' :"Street",
           'Ct'   : "Court",
           'Cir'  : "Circle",
           'Cr'   : "Court",
           'ave'  : 'Avenue',
           'Hwg'  : 'Highway',
           'Hwy'  : 'Highway',
           'Sq'   : "Square"}

# %% [markdown]
# **This menthod below audits for the street type names and updates any abbreviation which may not represent the standard ones for naming the streets**

# %%
def audit_street_type(street_types, street_name):
    m = street_type_re.search(street_name)
    if m:
        street_type = m.group()
        if street_type not in expected:
            street_types[street_type].add(street_name)

def is_street_name(elem):
    return (elem.attrib['k'] == "addr:street")

def audit(osmfile):
    osm_file = open(osmfile, "r")
    street_types = defaultdict(set)
    for event, elem in ET.iterparse(osm_file, events=("start",)):

        if elem.tag == "node" or elem.tag == "way":
            for tag in elem.iter("tag"):
                if is_street_name(tag):
                    audit_street_type(street_types, tag.attrib['v'])

    return street_types

# %%
sc_street_types = audit(sc_data)

# %%
pprint.pprint(dict(sc_street_types))
# Out:
# {'1': set(['Stewart Drive Suite #1']),
#  '201': set(['Great America Pkwy Ste 201']),
#  '6': set(['Martin Avenue #6']),
#  'Alameda': set(['The Alameda']),
#  'Ave': set(['Blake Ave',
#              'Cabrillo Ave',
#              'E Duane Ave',
#              'Seaboard Ave',
#              'The Alameda Ave']),
#  'Barcelona': set(['Calle de Barcelona']),
#  'Bellomy': set(['Bellomy']),
#  'Blvd': set(['Mission College Blvd', 'Stevens Creek Blvd']),
#  'CA': set(['Zanker Rd., San Jose, CA', 'Zanker Road, San Jose, CA']),
#  'Circle': set(['Freedom Circle',
#                 'Greenwood Circle',
#                 'Vista Club Circle',
#                 'vista Club Circle']),
#  'East': set(['Rio Robles East']),
#  'Expressway': set(['Central Expressway',
#                     'Lawrence Expressway',
#                     'San Tomas Expressway']),
#  'Franklin': set(['Franklin']),
#  'Luna': set(['Calle de Luna']),
#  'Madrid': set(['Corte de Madrid']),
#  'Plaza': set(['Rivermark Plaza']),
#  'Rd': set(['Homestead Rd', 'Wolfe Rd']),
#  'Real': set(['East El Camino Real', 'El Camino Real']),
#  'Row': set(['Santana Row']),
#  'Seville': set(['Corte de Seville']),
#  'St': set(['Casa Verde St', 'Monroe St']),
#  'Terrace': set(['Brea Terrace',
#                  'Fontana Terrace',
#                  'Hobart Terrace',
#                  'Karby Terrace',
#                  'Santa Rosalia Terrace']),
#  'Way': set(['Arata Way',
#              'Cisco Way',
#              'Epic Way',
#              'Holger Way',
#              'Marie P. DeBartolo Way',
#              'Moreland Way',
#              'Nandina Way',
#              'Rose Orchard Way',
#              'Sakura Way',
#              'San Luisito Way']),
#  'ave': set(['wilcox ave']),
#  'robles': set(['rio robles']),
#  'street': set(['N 1st street'])}

# %% [markdown]
# That's a lot less abbreviations than I was expecting to come up. It looks like the data is already cleaned up. None the less I found some abbr. like Rd,ave, St which we would update using the funtion below. We also update the **mapping{}** above looking at the result from street_types

# %%
# Updating the street names. This last function update_name is the last step of the process, which take the old name and update them with a better name

def update_street_name(name, mapping):

    m = street_type_re.search(name)
    # print "m.group:" + m.group()
    better_name = name
    
    if m:
        if m.group() in mapping.keys():
            better_street_type = mapping[m.group()]
            better_name = street_type_re.sub(better_street_type,name)
            
    return better_name

print '**************************BETTER NAMES**************************'
for street_type, ways in sc_street_types.iteritems():
    for name in ways:
        better_name = update_street_name(name, mapping)
        print name, "=>", better_name
# Out:
# **************************BETTER NAMES**************************
# Wolfe Rd => Wolfe Road
# Homestead Rd => Homestead Road
# N 1st street => N 1st Street
# Rose Orchard Way => Rose Orchard Way
# Holger Way => Holger Way
# Marie P. DeBartolo Way => Marie P. DeBartolo Way
# Cisco Way => Cisco Way
# Nandina Way => Nandina Way
# Sakura Way => Sakura Way
# San Luisito Way => San Luisito Way
# Epic Way => Epic Way
# Moreland Way => Moreland Way
# Arata Way => Arata Way
# wilcox ave => wilcox Avenue
# Greenwood Circle => Greenwood Circle
# Vista Club Circle => Vista Club Circle
# Freedom Circle => Freedom Circle
# vista Club Circle => vista Club Circle
# San Tomas Expressway => San Tomas Expressway
# Lawrence Expressway => Lawrence Expressway
# Central Expressway => Central Expressway
# The Alameda => The Alameda
# El Camino Real => El Camino Real
# East El Camino Real => East El Camino Real
# Rio Robles East => Rio Robles East
# Stewart Drive Suite #1 => Stewart Drive Suite #1
# Martin Avenue #6 => Martin Avenue #6
# Karby Terrace => Karby Terrace
# Fontana Terrace => Fontana Terrace
# Brea Terrace => Brea Terrace
# Santa Rosalia Terrace => Santa Rosalia Terrace
# Hobart Terrace => Hobart Terrace
# Great America Pkwy Ste 201 => Great America Pkwy Ste 201
# Bellomy => Bellomy
# Zanker Rd., San Jose, CA => Zanker Rd., San Jose, CA
# Zanker Road, San Jose, CA => Zanker Road, San Jose, CA
# Rivermark Plaza => Rivermark Plaza
# Calle de Barcelona => Calle de Barcelona
# Monroe St => Monroe Street
# Casa Verde St => Casa Verde Street
# Franklin => Franklin
# Corte de Madrid => Corte de Madrid
# Corte de Seville => Corte de Seville
# Calle de Luna => Calle de Luna
# rio robles => rio robles
# Mission College Blvd => Mission College Boulevard
# Stevens Creek Blvd => Stevens Creek Boulevard
# Blake Ave => Blake Avenue
# E Duane Ave => E Duane Avenue
# The Alameda Ave => The Alameda Avenue
# Seaboard Ave => Seaboard Avenue
# Cabrillo Ave => Cabrillo Avenue
# Santana Row => Santana Row

# %% [markdown]
# ## Zip Codes

# %% [markdown]
# We use similar technique above to clean any unconventional zipcodes found in our Santa Clara data

# %%
from collections import defaultdict

def audit_zipcode(invalid_zipcode,zipcode):
    twoDigits = zipcode[0:2]
    if not twoDigits.isdigit():
        invalid_zipcode[twoDigits].add(zipcode)
    
    elif twoDigits != 95:
        invalid_zipcode[twoDigits].add(zipcode)
        
def is_zipcode(elem):
    return (elem.attrib['k'] == "addr:postcode")

def audit_zip(osmfile):
    osm_file = open(osmfile, "r")
    invalid_zipcodes = defaultdict(set)
    for event, elem in ET.iterparse(osm_file, events=("start",)):

        if elem.tag == "node" or elem.tag == "way":
            for tag in elem.iter("tag"):
                if is_zipcode(tag):
                    audit_zipcode(invalid_zipcodes,tag.attrib['v'])

    return invalid_zipcodes

# %%
sc_zipcodes = audit_zip(sc_data)

pprint.pprint(dict(sc_zipcodes))
# Out:
# {'94': set(['94085', '94086', '94087', '94088-3453', '94089', '94089-2701']),
#  '95': set(['95002',
#             '95014',
#             '95014-0706',
#             '95014-0708',
#             '95014-0717',
#             '95014-0721',
#             '95014-0739',
#             '95014-2502',
#             '95014-2504',
#             '95014-2505',
#             '95014-2508',
#             '95014-2522',
#             '95014-2526',
#             '95014-2540',
#             '95014-2541',
#             '95014-2557',
#             '95014-2558',
#             '95014-3342',
#             '95014-3343',
#             '95014-3344',
#             '95014-3346',
#             '95014-3351',
#             '95014-3352',
#             '95014-3354',
#             '95014-3373',
#             '95014-3400',
#             '95014-3403',
#             '95014-3405',
#             '95014-3406',
#             '95014-3407',
#             '95014-3410',
#             '95014-3412',
#             '95014-3413',
#             '95014-3414',
#             '95014-3415',
#             '95014-3421',
#             '95014-3422',
#             '95014-3423',
#             '95014-3424',
#             '95014-3426',
#             '95014-3427',
#             '95014-3428',
#             '95014-3429',
#             '95014-3432',
#             '95014-3433',
#             '95014-3435',
#             '95014-3436',
#             '95014-3437',
#             '95014-3446',
#             '95014-3449',
#             '95014-3450',
#             '95014-3451',
#             '95014-3452',
#             '95014-3453',
#             '95014-3454',
#             '95014-3456',
#             '95014-3457',
#             '95014-3458',
#             '95014-346',
#             '95014-3460',
#             '95014-3462',
#             '95014-3463',
#             '95014-3465',
#             '95014-3468',
#             '95014-3471',
#             '95014-3474',
#             '95014-3475',
#             '95014-3477',
#             '95014-3478',
#             '95014-3479',
#             '95014-3480',
#             '95014-3481',
#             '95014-3483',
#             '95014-3484',
#             '95014-3487',
#             '95014-3488',
#             '95014-3489',
#             '95014-3490',
#             '95014-3491',
#             '95014-3496',
#             '95014-3497',
#             '95014-3499',
#             '95014-3500',
#             '95014-3501',
#             '95014-3502',
#             '95014-3503',
#             '95014-3504',
#             '95014-3506',
#             '95014-3516',
#             '95014-3518',
#             '95014-3519',
#             '95014-3520',
#             '95014-3521',
#             '95014-3522',
#             '95014-3523',
#             '95014-3524',
#             '95014-3525',
#             '95014-3526',
#             '95014-3527',
#             '95014-3528',
#             '95014-3529',
#             '95014-3532',
#             '95014-3533',
#             '95014-3535',
#             '95014-3537',
#             '95014-3538',
#             '95014-3539',
#             '95014-3540',
#             '95014-3541',
#             '95014-3542',
#             '95014-3543',
#             '95014-3544',
#             '95014-3545',
#             '95014-3546',
#             '95014-3547',
#             '95014-3548',
#             '95014-3549',
#             '95014-3551',
#             '95014-3552',
#             '95014-3553',
#             '95014-3557',
#             '95014-3558',
#             '95014-3564',
#             '95014-3565',
#             '95014-3566',
#             '95014-3601',
#             '95014-3602',
#             '95014-3603',
#             '95014-3629',
#             '95014-3630',
#             '95014-3631',
#             '95014-3632',
#             '95014-3633',
#             '95014-3634',
#             '95014-3635',
#             '95014-3636',
#             '95014-3637',
#             '95014-3638',
#             '95014-3639',
#             '95014-3640',
#             '95014-3641',
#             '95014-3642',
#             '95014-3643',
#             '95014-3644',
#             '95014-3645',
#             '95014-3646',
#             '95014-3647',
#             '95014-3648',
#             '95014-3650',
#             '95014-3653',
#             '95014-3654',
#             '95014-3655',
#             '95014-3656',
#             '95014-3657',
#             '95014-366',
#             '95014-3661',
#             '95014-3662',
#             '95014-3663',
#             '95014-3664',
#             '95014-3665',
#             '95014-3666',
#             '95014-3667',
#             '95014-3668',
#             '95014-3669',
#             '95014-3670',
#             '95014-3672',
#             '95014-3673',
#             '95014-3674',
#             '95014-3676',
#             '95014-3677',
#             '95014-3678',
#             '95014-3679',
#             '95014-3682',
#             '95014-3683',
#             '95014-3684',
#             '95014-3685',
#             '95014-3686',
#             '95014-3687',
#             '95014-3688',
#             '95014-3689',
#             '95014-3690',
#             '95014-3691',
#             '95014-3702',
#             '95014-3799',
#             '95014-3800',
#             '95014-3801',
#             '95014-3802',
#             '95014-3803',
#             '95014-3804',
#             '95014-3805',
#             '95014-3806',
#             '95014-3807',
#             '95014-3808',
#             '95014-3809',
#             '95014-3811',
#             '95014-3812',
#             '95014-3813',
#             '95014-3814',
#             '95014-3821',
#             '95014-3822',
#             '95014-3823',
#             '95014-3824',
#             '95014-3825',
#             '95014-3826',
#             '95014-3827',
#             '95014-3828',
#             '95014-3829',
#             '95014-3830',
#             '95014-3831',
#             '95014-3832',
#             '95014-3834',
#             '95014-3835',
#             '95014-3836',
#             '95014-3837',
#             '95014-3838',
#             '95014-3839',
#             '95014-3840',
#             '95014-3857',
#             '95014-3858',
#             '95014-3859',
#             '95014-3860',
#             '95014-3861',
#             '95014-3862',
#             '95014-3863',
#             '95014-3864',
#             '95014-3865',
#             '95014-3867',
#             '95014-3869',
#             '95014-3870',
#             '95014-3871',
#             '95014-3872',
#             '95014-3880',
#             '95014-3884',
#             '95014-4602',
#             '95014-4640',
#             '95014-4654',
#             '95014-4655',
#             '95014-4656',
#             '95014-4658',
#             '95014-4670',
#             '95014-4671',
#             '95014-4672',
#             '95014-7400',
#             '95014-7401',
#             '95014-7403',
#             '95014-7404',
#             '95014-7405',
#             '95014-7406',
#             '95014-7407',
#             '95014-7408',
#             '95014-7410',
#             '95014-7412',
#             '95014-7413',
#             '95014-7414',
#             '95014-7415',
#             '95014-7601',
#             '95014-7604',
#             '95014-7607',
#             '95014-7610',
#             '95014-7616',
#             '95014-7624',
#             '95014-7627',
#             '95014-763',
#             '95035',
#             '95050',
#             '95051',
#             '95052',
#             '95054',
#             '95110',
#             '95117',
#             '95126',
#             '95128',
#             '95129',
#             '95131',
#             '95134',
#             '95134-1358',
#             '95914']),
#  'CA': set(['CA 95054'])}

# %% [markdown]
# majority of the data looks clean. The clean zip code is summarised below. There are the format of 5 digits, 4 digits and 5 digits - 5 digits which are valid and need no formatting.

# %%
def update_name(zipcode):
    testNum = re.findall('[a-zA-Z]*', zipcode)
    if testNum:
        testNum = testNum[0]
    testNum.strip()
    if testNum == "CA":
        convertedZipcode = (re.findall(r'\d+', zipcode))
        if convertedZipcode:
            if convertedZipcode.__len__() == 2:
                return (re.findall(r'\d+', zipcode))[0] + "-" +(re.findall(r'\d+', zipcode))[1]
            else:
                return (re.findall(r'\d+', zipcode))[0]

for street_type, ways in sc_zipcodes.iteritems():
    for name in ways:
        better_name = update_name(name)
        print name, "=>", better_name
# Out:
# CA 95054 => 95054
# 95014-3463 => None
# 95014-3462 => None
# 95014-3670 => None
# 95014-3460 => None
# 95014-3676 => None
# 95014-3677 => None
# 95014-3465 => None
# 95014-3421 => None
# 95014-3678 => None
# 95014-3468 => None
# 95014-3373 => None
# 95014-3679 => None
# 95014-3603 => None
# 95014-0706 => None
# 95014-3807 => None
# 95014-0708 => None
# 95014-3824 => None
# 95014-3449 => None
# 95014-3674 => None
# 95014-3869 => None
# 95014-3867 => None
# 95014-3865 => None
# 95014-3864 => None
# 95014-3863 => None
# 95014-3862 => None
# 95014-3861 => None
# 95014-3860 => None
# 95014-4655 => None
# 95014-3602 => None
# 95014-3601 => None
# 95014-4656 => None
# 95014-4658 => None
# 95014-3840 => None
# 95014-3661 => None
# 95014-3414 => None
# 95014-3662 => None
# 95014-3412 => None
# 95014-3413 => None
# 95014-3410 => None
# 95014-3666 => None
# 95014-3669 => None
# 95014-3668 => None
# 95014-3813 => None
# 95014-2558 => None
# 95014-3487 => None
# 95014-3801 => None
# 95014-7415 => None
# 95014-3811 => None
# 95014-3633 => None
# 95131 => None
# 95134 => None
# 95014-3702 => None
# 95014-3552 => None
# 95014-3548 => None
# 95014-3549 => None
# 95014-7624 => None
# 95014-7627 => None
# 95014-3837 => None
# 95014-3540 => None
# 95014-3541 => None
# 95014-3542 => None
# 95014-3543 => None
# 95014-3544 => None
# 95014-3545 => None
# 95014-3546 => None
# 95014-3547 => None
# 95014-3405 => None
# 95014-3655 => None
# 95014-3407 => None
# 95014-3406 => None
# 95014-3650 => None
# 95014-3400 => None
# 95014-3403 => None
# 95014-3653 => None
# 95014-3522 => None
# 95014-3523 => None
# 95014-3520 => None
# 95014-3521 => None
# 95014-3526 => None
# 95014-3527 => None
# 95014-3524 => None
# 95014-3525 => None
# 95054 => None
# 95050 => None
# 95051 => None
# 95052 => None
# 95014-3640 => None
# 95014-3654 => None
# 95014-3799 => None
# 95014-3479 => None
# 95014-3880 => None
# 95128 => None
# 95129 => None
# 95014-3499 => None
# 95014-3496 => None
# 95014-4672 => None
# 95126 => None
# 95014-4670 => None
# 95014-3490 => None
# 95014-3491 => None
# 95014-3809 => None
# 95014-3808 => None
# 95014-7616 => None
# 95014-7610 => None
# 95014-3558 => None
# 95014-3557 => None
# 95014-3800 => None
# 95014-3803 => None
# 95014-3802 => None
# 95014-3553 => None
# 95014-3804 => None
# 95014-3551 => None
# 95014-3806 => None
# 95014-3539 => None
# 95014-3538 => None
# 95014-3684 => None
# 95014-3429 => None
# 95014-3672 => None
# 95014-3533 => None
# 95014-3532 => None
# 95014-3535 => None
# 95014-3537 => None
# 95014-3682 => None
# 95014-3427 => None
# 95014-3687 => None
# 95014-3656 => None
# 95014-3426 => None
# 95014-3634 => None
# 95014-3424 => None
# 95014-3489 => None
# 95014-3488 => None
# 95014-3415 => None
# 95014-3484 => None
# 95014-7601 => None
# 95014-7607 => None
# 95014-3480 => None
# 95014-3483 => None
# 95014-7604 => None
# 95014-3686 => None
# 95014-3838 => None
# 95014-3630 => None
# 95014-3834 => None
# 95914 => None
# 95014-2541 => None
# 95014-3631 => None
# 95014-3830 => None
# 95014-3831 => None
# 95014-3832 => None
# 95014-3437 => None
# 95014-3805 => None
# 95014-3641 => None
# 95014-3504 => None
# 95014-3506 => None
# 95014-3500 => None
# 95014-3501 => None
# 95014-3502 => None
# 95014-3503 => None
# 95014-3673 => None
# 95014-3644 => None
# 95014-2522 => None
# 95035 => None
# 95014-3814 => None
# 95014-3635 => None
# 95014-3823 => None
# 95014-3822 => None
# 95014-3821 => None
# 95014-3648 => None
# 95014-3827 => None
# 95014-3826 => None
# 95014-3825 => None
# 95014-3691 => None
# 95014-3643 => None
# 95014-3642 => None
# 95014-3432 => None
# 95014-3433 => None
# 95014-3647 => None
# 95014-3435 => None
# 95014-3436 => None
# 95014-4654 => None
# 95014-3458 => None
# 95014-3516 => None
# 95014-3452 => None
# 95014-3453 => None
# 95014-3450 => None
# 95014-3451 => None
# 95014-3456 => None
# 95014-3457 => None
# 95014-3454 => None
# 95014-3346 => None
# 95014-763 => None
# 95014-3344 => None
# 95014-0739 => None
# 95014-3342 => None
# 95014-3343 => None
# 95014-3519 => None
# 95002 => None
# 95014-366 => None
# 95014-3828 => None
# 95014-3646 => None
# 95014-3857 => None
# 95014-3645 => None
# 95014-3638 => None
# 95014-3428 => None
# 95014-7412 => None
# 95014-7413 => None
# 95014-7410 => None
# 95014-2526 => None
# 95014-3423 => None
# 95014-3422 => None
# 95014-3858 => None
# 95014-3859 => None
# 95014-3566 => None
# 95014-3564 => None
# 95014-3565 => None
# 95134-1358 => None
# 95014-3690 => None
# 95014-4602 => None
# 95014-3663 => None
# 95014-3446 => None
# 95014-3354 => None
# 95014-2557 => None
# 95014-3351 => None
# 95014-7414 => None
# 95014-3352 => None
# 95014-0721 => None
# 95014-3665 => None
# 95014 => None
# 95014-3664 => None
# 95014-3667 => None
# 95014-3632 => None
# 95014-3839 => None
# 95014-4640 => None
# 95014-7408 => None
# 95014-3639 => None
# 95014-3629 => None
# 95014-3812 => None
# 95014-3528 => None
# 95014-7401 => None
# 95014-7400 => None
# 95014-7403 => None
# 95014-7405 => None
# 95014-7404 => None
# 95014-7407 => None
# 95014-7406 => None
# 95014-3518 => None
# 95014-3478 => None
# 95014-3481 => None
# 95014-3689 => None
# 95014-3688 => None
# 95014-3474 => None
# 95014-3475 => None
# 95014-3685 => None
# 95014-3477 => None
# 95014-3683 => None
# 95014-3471 => None
# 95014-3636 => None
# 95014-3529 => None
# 95014-3835 => None
# 95014-346 => None
# 95014-0717 => None
# 95014-3836 => None
# 95014-3884 => None
# 95117 => None
# 95014-2540 => None
# 95110 => None
# 95014-3870 => None
# 95014-3871 => None
# 95014-3872 => None
# 95014-3829 => None
# 95014-3637 => None
# 95014-2505 => None
# 95014-2504 => None
# 95014-2502 => None
# 95014-3497 => None
# 95014-3657 => None
# 95014-4671 => None
# 95014-2508 => None
# 94089 => None
# 94088-3453 => None
# 94085 => None
# 94086 => None
# 94089-2701 => None
# 94087 => None

# %% [markdown]
#  # 3. MongoDB

# %% [markdown]
# In order to analyze our dataset in MongoDb we will need to convert the XML  to JSON. We will use the following set of rules learnt from the Case Study of the lectures:
# - you should process only 2 types of top level tags: "node" and "way"
# - all attributes of "node" and "way" should be turned into regular key/value pairs, except:
#     - attributes in the CREATED array should be added under a key "created"
#     - attributes for latitude and longitude should be added to a "pos" array,
#       for use in geospacial indexing. Make sure the values inside "pos" array are floats
#       and not strings.
# - if the second level tag "k" value contains problematic characters, it should be ignored
# - if the second level tag "k" value starts with "addr:", it should be added to a dictionary "address"
# - if the second level tag "k" value does not start with "addr:", but contains ":", you can
#   process it in a way that you feel is best. For example, you might split it into a two-level
#   dictionary like with "addr:", or otherwise convert the ":" to create a valid key.
# - if there is a second ":" that separates the type/direction of a street,
#   the tag should be ignored

# %%
# Preparing database for MongoDB
lower = re.compile(r'^([a-z]|_)*$')
lower_colon = re.compile(r'^([a-z]|_)*:([a-z]|_)*$')
problemchars = re.compile(r'[=\+/&<>;\'"\?%#$@\,\. \t\r\n]')
startswith_addr = re.compile(r'addr:')
startswith_street = re.compile(r'^street')

CREATED = [ "version", "changeset", "timestamp", "user", "uid"]
POS = ["lon", "lat"]

def shape_element(element):
    node = {}
        
    if element.tag == "node" or element.tag == "way" :
        # YOUR CODE HERE
        node['type'] = element.tag
        # initialize empty address
        address = {}
        # parsing through attributes
        for a in element.attrib:
            if a in CREATED:
                if 'created' not in node:
                    node['created'] = {}
                    node['created'][a] = element.get(a)
                elif a in ['lat','lon']:
                    continue
                else:
                    node[a] = element.get(a)
        #population
        if 'lat' in element.attrib and 'lon' in element.attrib:
            node['pos'] = [float(element.get('lat')), float(element.get('lon'))]
        
        #Parse 2nd- level tags
        for e in element:
            # parse second-level tags for ways and populate `node_refs`
            if e.tag == 'nd':
                if 'node_refs' not in node:
                    node['node_refs'] = []
                if 'ref' in e.attrib:
                    node['node_refs'].append(e.get('ref'))

            # throw out not-tag elements and elements without `k` or `v`
            if e.tag != 'tag' or 'k' not in e.attrib or 'v' not in e.attrib:
                continue
            key = e.get('k')
            val = e.get('v')

            # skip problematic characters
            if problemchars.search(key):
                continue

            # parse address k-v pairs
            elif startswith_addr.search(key):
                key = key.replace('addr:', '')
                address[key] = val

            # catch-all
            else:
                node[key] = val
        # compile address
        if len(address) > 0:
            node['address'] = {}
            street_full = None
            street_dict = {}
            street_format = ['prefix', 'name', 'type']
            # parse through address objects
            for key in address:
                val = address[key]
                if startswith_street.search(key):
                    if key == 'street':
                        street_full = val
                    elif 'street:' in key:
                        street_dict[key.replace('street:', '')] = val
                else:
                    node['address'][key] = val
            # assign street_full or fallback to compile street dict
            if street_full:
                node['address']['street'] = street_full
            elif len(street_dict) > 0:
                node['address']['street'] = ' '.join([street_dict[key] for key in street_format])
        return node
    else:
        return None

# %%
def process_map(file_in, pretty = False):
    file_out = "{0}.json".format(file_in)
    data = []
    with codecs.open(file_out, "w") as fo:
        for _, element in ET.iterparse(file_in):
            el = shape_element(element)
            if el:
                data.append(el)
                if pretty:
                    fo.write(json.dumps(el, indent=2)+"\n")
                else:
                    fo.write(json.dumps(el) + "\n")
    return data

# %%
process_map(sc_data)
# Out:
# [{'created': {'changeset': '16866449'},
#   'highway': 'traffic_signals',
#   'pos': [37.3531613, -122.0140663],
#   'timestamp': '2013-07-07T21:29:38Z',
#   'type': 'node',
#   'uid': '318696',
#   'user': 'n76',
#   'version': '21'},
#  {'created': {'changeset': '18300806'},
#   'pos': [37.3527232, -122.0129194],
#   'timestamp': '2013-10-11T16:32:56Z',
#   'type': 'node',
#   'uid': '1376118',
#   'user': 'ChrisZontine',
#   'version': '20'},
#  {'created': {'changeset': '9044962'},
#   'pos': [37.3522694, -122.0103794],
#   'timestamp': '2011-08-17T08:21:29Z',
#   'type': 'node',
#   'uid': '14293',
#   'user': 'KindredCoda',
#   'version': '19'},
#  {'created': {'changeset': '9044962'},
#   'pos': [37.3525316, -122.0122684],
#   'timestamp': '2011-08-17T08:21:29Z',
#   'type': 'node',
#   'uid': '14293',
#   'user': 'KindredCoda',
#   'version': '19'},
#  {'created': {'changeset': '9044962'},
#   'pos': [37.3523199, -122.0110571],
#   'timestamp': '2011-08-17T08:21:29Z',
#   'type': 'node',
#   'uid': '14293',
#   'user': 'KindredCoda',
#   'version': '19'},
#  {'created': {'changeset': '20818043'},
#   'pos': [37.3666158, -122.013768],
#   'timestamp': '2014-02-27T22:01:31Z',
#   'type': 'node',
#   'uid': '318696',
#   'user': 'n76',
#   'version': '8'},
#  {'created': {'changeset': '4949992'},
#   'pos': [37.3729016, -122.013795],
#   'timestamp': '2010-06-09T22:21:00Z',
#   'type': 'node',
#   'uid': '296587',
#   'user': 'bmhr',
#   'version': '6'},
#  {'created': {'changeset': '7124511'},
#   'pos': [37.3745913, -122.0137249],
#   'timestamp': '2011-01-29T17:07:13Z',
#   'type': 'node',
#   'uid': '201724',
#   'user': 'mk408',
#   'version': '12'},
#  {'created': {'changeset': '363058'},
#   'pos': [37.3758901, -122.0136194],
#   'timestamp': '2009-02-11T08:10:12Z',
#   'type': 'node',
#   'uid': '93800',
#   'user': 'Alan Vogt',
#   'version': '6'},
#  {'created': {'changeset': '7124511'},
#   'pos': [37.3796307, -122.0123887],
#   'timestamp': '2011-01-29T17:08:28Z',
#   'type': 'node',
#   'uid': '201724',
#   'user': 'mk408',
#   'version': '7'},
#  {'created': {'changeset': '7124511'},
#   'pos': [37.3800797, -122.0121596],
#   'timestamp': '2011-01-29T17:08:30Z',
#   'type': 'node',
#   'uid': '201724',
#   'user': 'mk408',
#   'version': '8'},
#  {'created': {'changeset': '7124511'},
#   'pos': [37.3804127, -122.0119681],
#   'timestamp': '2011-01-29T17:08:34Z',
#   'type': 'node',
#   'uid': '201724',
#   'user': 'mk408',
#   'version': '8'},
#  {'created': {'changeset': '363058'},
#   'pos': [37.381184, -122.011833],
#   'timestamp': '2009-02-11T08:10:13Z',
#   'type': 'node',
#   'uid': '93800',
#   'user': 'Alan Vogt',
#   'version': '6'},
#  {'created': {'changeset': '24359673'},
#   'pos': [37.3830944, -122.0129908],
#   'timestamp': '2014-07-25T22:53:53Z',
#   'type': 'node',
#   'uid': '590608',
#   'user': 'robertstack',
#   'version': '7'},
#  {'created': {'changeset': '24359673'},
#   'pos': [37.3833641, -122.0133298],
#   'timestamp': '2014-07-25T22:53:53Z',
#   'type': 'node',
#   'uid': '590608',
#   'user': 'robertstack',
#   'version': '7'},
#  {'created': {'changeset': '24359673'},
#   'pos': [37.3835778, -122.0137162],
#   'timestamp': '2014-07-25T22:53:53Z',
#   'type': 'node',
#   'uid': '590608',
#   'user': 'robertstack',
#   'version': '6'},
#  {'created': {'changeset': '36943114'},
#   'pos': [37.3980005, -122.0119465],
#   'timestamp': '2016-02-01T18:48:08Z',
#   'type': 'node',
#   'uid': '2748195',
#   'user': 'karitotp',
#   'version': '7'},
#  {'created': {'changeset': '16866449'},
#   'highway': 'traffic_signals',
#   'pos': [37.3529671, -122.0140679],
#   'timestamp': '2013-07-07T21:29:38Z',
#   'type': 'node',
#   'uid': '318696',
#   'user': 'n76',
#   'version': '25'},
#  {'created': {'changeset': '9044962'},
#   'pos': [37.3525659, -122.0130354],
#   'timestamp': '2011-08-17T07:53:29Z',
#   'type': 'node',
#   'uid': '14293',
#   'user': 'KindredCoda',
#   'version': '21'},
#  {'created': {'changeset': '31215083'},
#   'pos': [37.3523544, -122.0122361],
#   'timestamp': '2015-05-17T00:01:56Z',
#   'type': 'node',
#   'uid': '74705',
#   'user': 'Bike Mapper',
#   'version': '25'},
#  {'created': {'changeset': '9044962'},
#   'pos': [37.3522134, -122.0113415],
#   'timestamp': '2011-08-17T08:21:29Z',
#   'type': 'node',
#   'uid': '14293',
#   'user': 'KindredCoda',
#   'version': '22'},
#  {'created': {'changeset': '23082041'},
#   'pos': [37.3807647, -121.9599129],
#   'timestamp': '2014-06-22T14:37:20Z',
#   'type': 'node',
#   'uid': '1660455',
#   'user': 'juergenb22',
#   'version': '20'},
#  {'created': {'changeset': '36939372'},
#   'pos': [37.3834281, -121.9683921],
#   'timestamp': '2016-02-01T15:45:18Z',
#   'type': 'node',
#   'uid': '2748195',
#   'user': 'karitotp',
#   'version': '26'},
#  {'created': {'changeset': '12135372'},
#   'exit_to': 'Lawrence Expressway',
#   'highway': 'motorway_junction',
#   'pos': [37.3901447, -121.9921189],
#   'ref': '394',
#   'timestamp': '2012-07-06T22:08:20Z',
#   'type': 'node',
#   'uid': '169004',
#   'user': 'oldtopos',
#   'version': '28'},
#  {'created': {'changeset': '13575017'},
#   'highway': 'traffic_signals',
#   'pos': [37.3752444, -122.0136975],
#   'source:highway': 'survey',
#   'timestamp': '2012-10-21T02:40:09Z',
#   'type': 'node',
#   'uid': '11776',
#   'user': 'Marcus Wolschon',
#   'version': '11'},
#  {'created': {'changeset': '28807896'},
#   'pos': [37.3514258, -122.0142844],
#   'timestamp': '2015-02-12T20:35:29Z',
#   'type': 'node',
#   'uid': '318696',
#   'user': 'n76',
#   'version': '7'},
#  {'created': {'changeset': '793775'},
#   'pos': [37.3373924, -122.0141803],
#   'timestamp': '2008-11-25T08:39:05Z',
#   'type': 'node',
#   'uid': '54598',
#   'user': 'adbrown',
#   'version': '4'},
#  {'created': {'changeset': '31334304'},
#   'pos': [37.3277617, -122.0142251],
#   'timestamp': '2015-05-21T06:17:12Z',
#   'type': 'node',
#   'uid': '202256',
#   'user': 'Telecas',
#   'version': '7'},
#  {'created': {'changeset': '31334304'},
#   'pos': [37.3286255, -122.013519],
#   'timestamp': '2015-05-21T06:17:12Z',
#   'type': 'node',
#   'uid': '202256',
#   'user': 'Telecas',
#   'version': '4'},
#  {'created': {'changeset': '31334304'},
#   'pos': [37.328641, -122.0123593],
#   'timestamp': '2015-05-21T06:17:12Z',
#   'type': 'node',
#   'uid': '202256',
#   'user': 'Telecas',
#   'version': '3'},
#  {'created': {'changeset': '441629'},
#   'created_by': 'JOSM',
#   'pos': [37.3279039, -122.0134944],
#   'timestamp': '2007-11-08T19:23:11Z',
#   'type': 'node',
#   'uid': '6157',
#   'user': 'raf',
#   'version': '3'},
#  {'created': {'changeset': '31334304'},
#   'pos': [37.3276935, -122.0139891],
#   'timestamp': '2015-05-21T06:17:12Z',
#   'type': 'node',
#   'uid': '202256',
#   'user': 'Telecas',
#   'version': '6'},
#  {'created': {'changeset': '24413610'},
#   'pos': [37.3781276, -121.9483055],
#   'timestamp': '2014-07-29T01:42:47Z',
#   'type': 'node',
#   'uid': '28775',
#   'user': 'StellanL',
#   'version': '21'},
#  {'created': {'changeset': '20468678'},
#   'pos': [37.3688113, -122.013612],
#   'timestamp': '2014-02-09T16:59:41Z',
#   'type': 'node',
#   'uid': '169004',
#   'user': 'oldtopos',
#   'version': '6'},
#  {'created': {'changeset': '2730399'},
#   'pos': [37.3835449, -122.0142272],
#   'timestamp': '2009-10-03T23:32:45Z',
#   'type': 'node',
#   'uid': '81024',
#   'user': 'wallclimber21',
#   'version': '4'},
#  {'created': {'changeset': '4144270'},
#   'pos': [37.3551116, -121.9455568],
#   'timestamp': '2010-03-16T15:49:45Z',
#   'type': 'node',
#   'uid': '201724',
#   'user': 'mk408',
#   'version': '21'},
#  {'created': {'changeset': '793775'},
#   'pos': [37.3557034, -121.9433917],
#   'timestamp': '2008-11-25T07:07:19Z',
#   'type': 'node',
#   'uid': '54598',
#   'user': 'adbrown',
#   'version': '19'},
#  {'created': {'changeset': '32109704'},
#   'highway': 'traffic_signals',
#   'pos': [37.3530879, -121.9383309],
#   'timestamp': '2015-06-21T05:07:50Z',
#   'type': 'node',
#   'uid': '33757',
#   'user': 'Minh Nguyen',
#   'version': '33'},
#  {'created': {'changeset': '32109704'},
#   'crossing': 'zebra',
#   'highway': 'crossing',
#   'pos': [37.3519373, -121.9370983],
#   'timestamp': '2015-06-21T05:07:49Z',
#   'type': 'node',
#   'uid': '33757',
#   'user': 'Minh Nguyen',
#   'version': '26'},
#  {'created': {'changeset': '22358519'},
#   'pos': [37.3553117, -121.9451537],
#   'timestamp': '2014-05-15T19:03:05Z',
#   'type': 'node',
#   'uid': '595221',
#   'user': 'matthieun',
#   'version': '21'},
#  {'created': {'changeset': '19944833'},
#   'pos': [37.3526838, -121.9518915],
#   'timestamp': '2014-01-11T23:24:45Z',
#   'type': 'node',
#   'uid': '318696',
#   'user': 'n76',
#   'version': '18'},
#  {'created': {'changeset': '32400887'},
#   'pos': [37.3555385, -121.9442251],
#   'timestamp': '2015-07-03T23:30:10Z',
#   'type': 'node',
#   'uid': '33757',
#   'user': 'Minh Nguyen',
#   'version': '15'},
#  {'created': {'changeset': '32904574'},
#   'pos': [37.355419, -121.9430954],
#   'timestamp': '2015-07-27T09:12:43Z',
#   'type': 'node',
#   'uid': '33757',
#   'user': 'Minh Nguyen',
#   'version': '15'},
#  {'created': {'changeset': '32400887'},
#   'highway': 'traffic_signals',
#   'pos': [37.3530397, -121.9385683],
#   'timestamp': '2015-07-03T23:30:10Z',
#   'type': 'node',
#   'uid': '33757',
#   'user': 'Minh Nguyen',
#   'version': '26'},
#  {'created': {'changeset': '32109704'},
#   'crossing': 'zebra',
#   'highway': 'crossing',
#   'pos': [37.3521025, -121.9374694],
#   'timestamp': '2015-06-21T05:07:49Z',
#   'type': 'node',
#   'uid': '33757',
#   'user': 'Minh Nguyen',
#   'version': '17'},
#  {'created': {'changeset': '8422366'},
#   'pos': [37.426758, -121.921713],
#   'timestamp': '2011-06-13T06:58:07Z',
#   'type': 'node',
#   'uid': '14293',
#   'user': 'KindredCoda',
#   'version': '6'},
#  {'created': {'changeset': '8241098'},
#   'pos': [37.3172777, -121.9347149],
#   'timestamp': '2011-05-25T02:48:32Z',
#   'type': 'node',
#   'uid': '14293',
#   'user': 'KindredCoda',
#   'version': '47'},
#  {'created': {'changeset': '8231395'},
#   'pos': [37.3282903, -122.0142766],
#   'timestamp': '2011-05-23T23:51:48Z',
#   'type': 'node',
#   'uid': '14293',
#   'user': 'KindredCoda',
#   'version': '11'},
#  {'created': {'changeset': '36941154'},
#   'pos': [37.3744614, -121.9510007],
#   'timestamp': '2016-02-01T17:15:32Z',
#   'type': 'node',
#   'uid': '2748195',
#   'user': 'karitotp',
#   'version': '8'},
#  {'created': {'changeset': '36938880'},
#   'pos': [37.3746186, -121.9753002],
#   'timestamp': '2016-02-01T15:21:29Z',
#   'type': 'node',
#   'uid': '2748195',
#   'user': 'karitotp',
#   'version': '9'},
#  {'created': {'changeset': '794494'},
#   'pos': [37.3773825, -121.9799316],
#   'timestamp': '2009-03-12T01:10:07Z',
#   'type': 'node',
#   'uid': '100744',
#   'user': 'fennecfoxen',
#   'version': '11'},
#  {'created': {'changeset': '13757040'},
#   'pos': [37.3776145, -122.0019069],
#   'timestamp': '2012-11-05T06:33:45Z',
#   'type': 'node',
#   'uid': '47892',
#   'user': 'richlv',
#   'version': '8'},
#  {'created': {'changeset': '22783625'},
#   'pos': [37.3766569, -122.006121],
#   'timestamp': '2014-06-06T21:26:05Z',
#   'type': 'node',
#   'uid': '771165',
#   'user': 'LXT',
#   'version': '6'},
#  {'created': {'changeset': '28601952'},
#   'pos': [37.3766796, -122.0070542],
#   'timestamp': '2015-02-04T00:01:01Z',
#   'type': 'node',
#   'uid': '595221',
#   'user': 'matthieun',
#   'version': '8'},
#  {'created': {'changeset': '28601952'},
#   'pos': [37.3770987, -122.0089047],
#   'timestamp': '2015-02-04T00:01:01Z',
#   'type': 'node',
#   'uid': '595221',
#   'user': 'matthieun',
#   'version': '9'},
#  {'created': {'changeset': '7124511'},
#   'highway': 'traffic_signals',
#   'pos': [37.3785814, -122.012721],
#   'timestamp': '2011-01-29T17:08:29Z',
#   'type': 'node',
#   'uid': '201724',
#   'user': 'mk408',
#   'version': '11'},
#  {'created': {'changeset': '794494'},
#   'pos': [37.3778414, -121.9813732],
#   'timestamp': '2009-03-12T01:12:03Z',
#   'type': 'node',
#   'uid': '100744',
#   'user': 'fennecfoxen',
#   'version': '14'},
#  {'created': {'changeset': '39276833'},
#   'pos': [37.3744227, -121.9590346],
#   'timestamp': '2016-05-12T20:01:09Z',
#   'type': 'node',
#   'uid': '1829683',
#   'user': 'Luis36995',
#   'version': '8'},
#  {'created': {'changeset': '8233100'},
#   'pos': [37.3189023, -121.9913763],
#   'timestamp': '2011-05-24T08:32:22Z',
#   'type': 'node',
#   'uid': '14293',
#   'user': 'KindredCoda',
#   'version': '32'},
#  {'created': {'changeset': '36938880'},
#   'pos': [37.375421, -121.9769681],
#   'timestamp': '2016-02-01T15:21:29Z',
#   'type': 'node',
#   'uid': '2748195',
#   'user': 'karitotp',
#   'version': '11'},
#  {'created': {'changeset': '20817845'},
#   'pos': [37.4028735, -122.0102919],
#   'timestamp': '2014-02-27T21:51:07Z',
#   'type': 'node',
#   'uid': '318696',
#   'user': 'n76',
#   'version': '30'},
#  {'created': {'changeset': '29670773'},
#   'pos': [37.4030294, -122.0102364],
#   'timestamp': '2015-03-23T05:32:20Z',
#   'type': 'node',
#   'uid': '2763448',
#   'user': 'Daniel_Caldwell',
#   'version': '26'},
#  {'created': {'changeset': '6776772'},
#   'pos': [37.4053195, -122.009538],
#   'timestamp': '2010-12-27T12:02:26Z',
#   'type': 'node',
#   'uid': '14293',
#   'user': 'KindredCoda',
#   'version': '6'},
#  {'created': {'changeset': '865564'},
#   'pos': [37.4034494, -121.9995614],
#   'timestamp': '2009-03-28T08:13:47Z',
#   'type': 'node',
#   'uid': '28775',
#   'user': 'StellanL',
#   'version': '24'},
#  {'created': {'changeset': '865564'},
#   'pos': [37.4032474, -122.0052385],
#   'timestamp': '2009-03-28T08:13:47Z',
#   'type': 'node',
#   'uid': '28775',
#   'user': 'StellanL',
#   'version': '18'},
#  {'created': {'changeset': '4090955'},
#   'pos': [37.4024513, -122.0075911],
#   'timestamp': '2010-03-10T16:34:53Z',
#   'type': 'node',
#   'uid': '201724',
#   'user': 'mk408',
#   'version': '19'},
#  {'created': {'changeset': '28196530'},
#   'pos': [37.4064644, -122.0095454],
#   'timestamp': '2015-01-16T21:38:50Z',
#   'type': 'node',
#   'uid': '28775',
#   'user': 'StellanL',
#   'version': '13'},
#  {'created': {'changeset': '39147451'},
#   'pos': [37.4077414, -122.0101073],
#   'timestamp': '2016-05-06T16:10:16Z',
#   'type': 'node',
#   'uid': '2226712',
#   'user': 'dannykath',
#   'version': '10'},
#  {'created': {'changeset': '20817845'},
#   'pos': [37.4087599, -122.0109726],
#   'timestamp': '2014-02-27T21:51:07Z',
#   'type': 'node',
#   'uid': '318696',
#   'user': 'n76',
#   'version': '25'},
#  {'created': {'changeset': '20275150'},
#   'pos': [37.4085051, -122.01106],
#   'timestamp': '2014-01-29T23:31:49Z',
#   'type': 'node',
#   'uid': '318696',
#   'user': 'n76',
#   'version': '10'},
#  {'created': {'changeset': '25711289'},
#   'pos': [37.4073636, -122.0114517],
#   'timestamp': '2014-09-27T18:27:11Z',
#   'type': 'node',
#   'uid': '318696',
#   'user': 'n76',
#   'version': '4'},
#  {'created': {'changeset': '36943776'},
#   'pos': [37.4060422, -122.01349],
#   'timestamp': '2016-02-01T19:18:46Z',
#   'type': 'node',
#   'uid': '2748195',
#   'user': 'karitotp',
#   'version': '5'},
#  {'created': {'changeset': '20303686'},
#   'pos': [37.4025145, -122.0068589],
#   'timestamp': '2014-01-31T17:35:21Z',
#   'type': 'node',
#   'uid': '318696',
#   'user': 'n76',
#   'version': '20'},
#  {'created': {'changeset': '865564'},
#   'pos': [37.4033405, -122.0044299],
#   'timestamp': '2009-03-28T08:13:47Z',
#   'type': 'node',
#   'uid': '28775',
#   'user': 'StellanL',
#   'version': '18'},
#  {'created': {'changeset': '8943068'},
#   'pos': [37.4228621, -121.9257204],
#   'timestamp': '2011-08-07T00:40:05Z',
#   'type': 'node',
#   'uid': '207745',
#   'user': 'NE2',
#   'version': '6'},
#  {'created': {'changeset': '6784016'},
#   'pos': [37.4225718, -121.9286509],
#   'timestamp': '2010-12-28T01:07:33Z',
#   'type': 'node',
#   'uid': '14293',
#   'user': 'KindredCoda',
#   'version': '4'},
#  {'created': {'changeset': '6784016'},
#   'pos': [37.4221458, -121.9318293],
#   'timestamp': '2010-12-28T01:18:07Z',
#   'type': 'node',
#   'uid': '14293',
#   'user': 'KindredCoda',
#   'version': '4'},
#  {'created': {'changeset': '4656002'},
#   'pos': [37.4200088, -121.9413075],
#   'timestamp': '2010-05-10T05:36:21Z',
#   'type': 'node',
#   'uid': '14293',
#   'user': 'KindredCoda',
#   'version': '5'},
#  {'created': {'changeset': '4656002'},
#   'pos': [37.4196381, -121.9429383],
#   'timestamp': '2010-05-10T05:36:22Z',
#   'type': 'node',
#   'uid': '14293',
#   'user': 'KindredCoda',
#   'version': '4'},
#  {'created': {'changeset': '4635988'},
#   'pos': [37.4194336, -121.9446575],
#   'timestamp': '2010-05-08T06:39:35Z',
#   'type': 'node',
#   'uid': '14293',
#   'user': 'KindredCoda',
#   'version': '4'},
#  {'created': {'changeset': '4635988'},
#   'pos': [37.4194421, -121.9525163],
#   'timestamp': '2010-05-08T06:39:06Z',
#   'type': 'node',
#   'uid': '14293',
#   'user': 'KindredCoda',
#   'version': '4'},
#  {'created': {'changeset': '4635988'},
#   'pos': [37.419408, -121.9579639],
#   'timestamp': '2010-05-08T06:38:24Z',
#   'type': 'node',
#   'uid': '14293',
#   'user': 'KindredCoda',
#   'version': '3'},
#  {'created': {'changeset': '4635988'},
#   'pos': [37.4192696, -121.9606193],
#   'timestamp': '2010-05-08T06:37:57Z',
#   'type': 'node',
#   'uid': '14293',
#   'user': 'KindredCoda',
#   'version': '3'},
#  {'created': {'changeset': '8233100'},
#   'pos': [37.3186125, -121.990474],
#   'timestamp': '2011-05-24T08:32:22Z',
#   'type': 'node',
#   'uid': '14293',
#   'user': 'KindredCoda',
#   'version': '34'},
#  {'created': {'changeset': '8233100'},
#   'pos': [37.3182335, -121.9885677],
#   'timestamp': '2011-05-24T08:32:22Z',
#   'type': 'node',
#   'uid': '14293',
#   'user': 'KindredCoda',
#   'version': '33'},
#  {'created': {'changeset': '8233100'},
#   'pos': [37.3181713, -121.9870925],
#   'timestamp': '2011-05-24T08:32:22Z',
#   'type': 'node',
#   'uid': '14293',
#   'user': 'KindredCoda',
#   'version': '33'},
#  {'created': {'changeset': '8233296'},
#   'pos': [37.3182056, -121.9810551],
#   'timestamp': '2011-05-24T09:00:12Z',
#   'type': 'node',
#   'uid': '14293',
#   'user': 'KindredCoda',
#   'version': '33'},
#  {'created': {'changeset': '8233296'},
#   'pos': [37.3181601, -121.9790801],
#   'timestamp': '2011-05-24T09:00:12Z',
#   'type': 'node',
#   'uid': '14293',
#   'user': 'KindredCoda',
#   'version': '34'},
#  {'created': {'changeset': '8233296'},
#   'pos': [37.3179476, -121.9771151],
#   'timestamp': '2011-05-24T09:00:12Z',
#   'type': 'node',
#   'uid': '14293',
#   'user': 'KindredCoda',
#   'version': '33'},
#  {'created': {'changeset': '8233296'},
#   'pos': [37.3171176, -121.9743554],
#   'timestamp': '2011-05-24T09:00:12Z',
#   'type': 'node',
#   'uid': '14293',
#   'user': 'KindredCoda',
#   'version': '32'},
#  {'created': {'changeset': '8233296'},
#   'pos': [37.3166276, -121.9724871],
#   'timestamp': '2011-05-24T09:00:12Z',
#   'type': 'node',
#   'uid': '14293',
#   'user': 'KindredCoda',
#   'version': '32'},
#  {'created': {'changeset': '8233296'},
#   'pos': [37.3164102, -121.9695545],
#   'timestamp': '2011-05-24T09:00:12Z',
#   'type': 'node',
#   'uid': '14293',
#   'user': 'KindredCoda',
#   'version': '33'},
#  {'created': {'changeset': '8232841'},
#   'pos': [37.3165294, -121.9657714],
#   'timestamp': '2011-05-24T07:55:03Z',
#   'type': 'node',
#   'uid': '14293',
#   'user': 'KindredCoda',
#   'version': '32'},
#  {'created': {'changeset': '8232841'},
#   'pos': [37.3165116, -121.9582873],
#   'timestamp': '2011-05-24T07:55:03Z',
#   'type': 'node',
#   'uid': '14293',
#   'user': 'KindredCoda',
#   'version': '30'},
#  {'created': {'changeset': '10826343'},
#   'pos': [37.3167178, -121.9516384],
#   'timestamp': '2012-02-29T10:13:05Z',
#   'type': 'node',
#   'uid': '14293',
#   'user': 'KindredCoda',
#   'version': '48'},
#  {'created': {'changeset': '21368423'},
#   'pos': [37.3496042, -121.9961802],
#   'timestamp': '2014-03-28T16:19:54Z',
#   'type': 'node',
#   'uid': '595221',
#   'user': 'matthieun',
#   'version': '7'},
#  {'created': {'changeset': '794494'},
#   'pos': [37.3477486, -121.9959842],
#   'timestamp': '2009-03-12T01:13:33Z',
#   'type': 'node',
#   'uid': '100744',
#   'user': 'fennecfoxen',
#   'version': '3'},
#  {'created': {'changeset': '30174277'},
#   'pos': [37.3229482, -121.9964556],
#   'timestamp': '2015-04-12T21:42:45Z',
#   'type': 'node',
#   'uid': '318696',
#   'user': 'n76',
#   'version': '13'},
#  {'created': {'changeset': '19963761'},
#   'pos': [37.3229892, -121.9925257],
#   'timestamp': '2014-01-13T00:13:18Z',
#   'type': 'node',
#   'uid': '318696',
#   'user': 'n76',
#   'version': '10'},
#  {'created': {'changeset': '21630577'},
#   'pos': [37.3524714, -121.9958616],
#   'timestamp': '2014-04-11T17:02:22Z',
#   'type': 'node',
#   'uid': '318696',
#   'user': 'n76',
#   'version': '21'},
#  {'created': {'changeset': '21630577'},
#   'pos': [37.3522114, -121.995837],
#   'timestamp': '2014-04-11T17:02:22Z',
#   'type': 'node',
#   'uid': '318696',
#   'user': 'n76',
#   'version': '26'},
#  {'created': {'changeset': '794494'},
#   'pos': [37.3263656, -121.9956697],
#   'timestamp': '2009-03-12T01:13:29Z',
#   'type': 'node',
#   'uid': '100744',
#   'user': 'fennecfoxen',
#   'version': '6'},
#  {'created': {'changeset': '21368423'},
#   'pos': [37.3473766, -121.9957189],
#   'timestamp': '2014-03-28T16:19:54Z',
#   'type': 'node',
#   'uid': '595221',
#   'user': 'matthieun',
#   'version': '8'},
#  {'created': {'changeset': '21368423'},
#   'pos': [37.3493932, -121.9959283],
#   'timestamp': '2014-03-28T16:19:54Z',
#   'type': 'node',
#   'uid': '595221',
#   'user': 'matthieun',
#   'version': '10'},
#  {'created': {'changeset': '23082041'},
#   'pos': [37.3793931, -121.9550441],
#   'timestamp': '2014-06-22T14:37:20Z',
#   'type': 'node',
#   'uid': '1660455',
#   'user': 'juergenb22',
#   'version': '21'},
#  {'created': {'changeset': '23082041'},
#   'pos': [37.3749596, -121.9332728],
#   'timestamp': '2014-06-22T14:37:20Z',
#   'type': 'node',
#   'uid': '1660455',
#   'user': 'juergenb22',
#   'version': '23'},
#  {'created': {'changeset': '749969'},
#   'pos': [37.3728127, -121.9241955],
#   'timestamp': '2008-11-15T08:55:23Z',
#   'type': 'node',
#   'uid': '54598',
#   'user': 'adbrown',
#   'version': '18'},
#  {'created': {'changeset': '36946700'},
#   'pos': [37.3449872, -121.9233564],
#   'timestamp': '2016-02-01T21:35:29Z',
#   'type': 'node',
#   'uid': '2748195',
#   'user': 'karitotp',
#   'version': '19'},
#  {'created': {'changeset': '33058026'},
#   'pos': [37.3423265, -121.926149],
#   'timestamp': '2015-08-02T22:50:59Z',
#   'type': 'node',
#   'uid': '33757',
#   'user': 'Minh Nguyen',
#   'version': '14'},
#  {'created': {'changeset': '8240967'},
#   'pos': [37.3201499, -121.9396569],
#   'timestamp': '2011-05-25T02:14:15Z',
#   'type': 'node',
#   'uid': '14293',
#   'user': 'KindredCoda',
#   'version': '9'},
#  {'created': {'changeset': '8241207'},
#   'pos': [37.316932, -121.9200313],
#   'timestamp': '2011-05-25T03:43:16Z',
#   'type': 'node',
#   'uid': '14293',
#   'user': 'KindredCoda',
#   'version': '20'},
#  {'created': {'changeset': '8241207'},
#   'pos': [37.3167455, -121.9299778],
#   'timestamp': '2011-05-25T03:43:16Z',
#   'type': 'node',
#   'uid': '14293',
#   'user': 'KindredCoda',
#   'version': '47'},
#  {'created': {'changeset': '8241207'},
#   'pos': [37.3169268, -121.9299228],
#   'timestamp': '2011-05-25T03:43:16Z',
#   'type': 'node',
#   'uid': '14293',
#   'user': 'KindredCoda',
#   'version': '17'},
#  {'created': {'changeset': '8241207'},
#   'pos': [37.316767, -121.9207252],
#   'timestamp': '2011-05-25T03:43:16Z',
#   'type': 'node',
#   'uid': '14293',
#   'user': 'KindredCoda',
#   'version': '45'},
#  {'created': {'changeset': '3940825'},
#   'pos': [37.3907955, -121.996131],
#   'timestamp': '2010-02-22T04:38:10Z',
#   'type': 'node',
#   'uid': '201724',
#   'user': 'mk408',
#   'version': '14'},
#  {'created': {'changeset': '32487234'},
#   'pos': [37.3674251, -121.9963624],
#   'timestamp': '2015-07-08T04:56:47Z',
#   'type': 'node',
#   'uid': '33757',
#   'user': 'Minh Nguyen',
#   'version': '8'},
#  {'created': {'changeset': '21368275'},
#   'pos': [37.3747219, -121.9960957],
#   'timestamp': '2014-03-28T16:11:38Z',
#   'type': 'node',
#   'uid': '595221',
#   'user': 'matthieun',
#   'version': '7'},
#  {'created': {'changeset': '794494'},
#   'pos': [37.3723216, -121.9965079],
#   'timestamp': '2009-03-12T01:12:32Z',
#   'type': 'node',
#   'uid': '100744',
#   'user': 'fennecfoxen',
#   'version': '7'},
#  {'created': {'changeset': '794494'},
#   'pos': [37.3691347, -121.9965186],
#   'timestamp': '2009-03-12T01:12:32Z',
#   'type': 'node',
#   'uid': '100744',
#   'user': 'fennecfoxen',
#   'version': '7'},
#  {'created': {'changeset': '32487234'},
#   'pos': [37.3670371, -121.9965797],
#   'timestamp': '2015-07-08T04:56:48Z',
#   'type': 'node',
#   'uid': '33757',
#   'user': 'Minh Nguyen',
#   'version': '3'},
#  {'created': {'changeset': '39213902'},
#   'pos': [37.3656505, -122.0138936],
#   'timestamp': '2016-05-10T11:57:43Z',
#   'type': 'node',
#   'uid': '2644101',
#   'user': 'Chetan_Gowda',
#   'version': '5'},
#  {'created': {'changeset': '7124511'},
#   'highway': 'traffic_signals',
#   'pos': [37.3779206, -122.0129488],
#   'timestamp': '2011-01-29T17:08:03Z',
#   'type': 'node',
#   'uid': '201724',
#   'user': 'mk408',
#   'version': '10'},
#  {'created': {'changeset': '760322'},
#   'pos': [37.4045692, -122.0100298],
#   'timestamp': '2008-11-17T18:20:44Z',
#   'type': 'node',
#   'uid': '54598',
#   'user': 'adbrown',
#   'version': '4'},
#  {'created': {'changeset': '4471964'},
#   'pos': [37.3959547, -122.0127012],
#   'timestamp': '2010-04-19T20:21:03Z',
#   'type': 'node',
#   'uid': '14293',
#   'user': 'KindredCoda',
#   'version': '14'},
#  {'created': {'changeset': '794494'},
#   'pos': [37.3770811, -122.0094827],
#   'timestamp': '2009-03-12T01:08:14Z',
#   'type': 'node',
#   'uid': '100744',
#   'user': 'fennecfoxen',
#   'version': '6'},
#  {'created': {'changeset': '794494'},
#   'pos': [37.3764959, -122.0056832],
#   'timestamp': '2009-03-12T01:08:14Z',
#   'type': 'node',
#   'uid': '100744',
#   'user': 'fennecfoxen',
#   'version': '5'},
#  {'created': {'changeset': '22783625'},
#   'pos': [37.3774303, -122.0018489],
#   'timestamp': '2014-06-06T21:26:05Z',
#   'type': 'node',
#   'uid': '771165',
#   'user': 'LXT',
#   'version': '8'},
#  {'created': {'changeset': '38577740'},
#   'pos': [37.3775696, -121.9957192],
#   'timestamp': '2016-04-15T05:41:46Z',
#   'type': 'node',
#   'uid': '119881',
#   'user': 'claysmalley',
#   'version': '10'},
#  {'created': {'changeset': '6776772'},
#   'pos': [37.4057797, -122.0094736],
#   'timestamp': '2010-12-27T12:02:30Z',
#   'type': 'node',
#   'uid': '14293',
#   'user': 'KindredCoda',
#   'version': '8'},
#  {'created': {'changeset': '6776772'},
#   'pos': [37.4074714, -122.0099457],
#   'timestamp': '2010-12-27T11:58:13Z',
#   'type': 'node',
#   'uid': '14293',
#   'user': 'KindredCoda',
#   'version': '9'},
#  {'created': {'changeset': '20275150'},
#   'highway': 'traffic_signals',
#   'pos': [37.4069625, -122.0114134],
#   'timestamp': '2014-01-29T23:31:49Z',
#   'type': 'node',
#   'uid': '318696',
#   'user': 'n76',
#   'version': '11'},
#  {'created': {'changeset': '20817845'},
#   'pos': [37.4027714, -122.0103282],
#   'timestamp': '2014-02-27T21:51:07Z',
#   'type': 'node',
#   'uid': '318696',
#   'user': 'n76',
#   'version': '7'},
#  {'created': {'changeset': '865564'},
#   'pos': [37.4028205, -122.010037],
#   'timestamp': '2009-03-28T08:05:58Z',
#   'type': 'node',
#   'uid': '28775',
#   'user': 'StellanL',
#   'version': '25'},
#  {'created': {'changeset': '865564'},
#   'pos': [37.4046669, -122.0097145],
#   'timestamp': '2009-03-28T07:48:31Z',
#   'type': 'node',
#   'uid': '28775',
#   'user': 'StellanL',
#   'version': '6'},
#  {'created': {'changeset': '6776772'},
#   'pos': [37.4050297, -122.0104714],
#   'timestamp': '2010-12-27T12:05:25Z',
#   'type': 'node',
#   'uid': '14293',
#   'user': 'KindredCoda',
#   'version': '2'},
#  {'created': {'changeset': '20817845'},
#   'pos': [37.4071882, -122.0098245],
#   'timestamp': '2014-02-27T21:51:07Z',
#   'type': 'node',
#   'uid': '318696',
#   'user': 'n76',
#   'version': '14'},
#  {'created': {'changeset': '4471964'},
#   'pos': [37.3963447, -122.0125054],
#   'timestamp': '2010-04-19T20:21:52Z',
#   'type': 'node',
#   'uid': '14293',
#   'user': 'KindredCoda',
#   'version': '7'},
#  {'created': {'changeset': '4471964'},
#   'pos': [37.3963681, -122.0126261],
#   'timestamp': '2010-04-19T20:21:56Z',
#   'type': 'node',
#   'uid': '14293',
#   'user': 'KindredCoda',
#   'version': '5'},
#  {'created': {'changeset': '28601935'},
#   'pos': [37.3782707, -122.0126206],
#   'timestamp': '2015-02-03T23:59:51Z',
#   'type': 'node',
#   'uid': '595221',
#   'user': 'matthieun',
#   'version': '9'},
#  {'created': {'changeset': '28601935'},
#   'pos': [37.3784783, -122.0132574],
#   'timestamp': '2015-02-03T23:59:51Z',
#   'type': 'node',
#   'uid': '595221',
#   'user': 'matthieun',
#   'version': '13'},
#  {'created': {'changeset': '7124511'},
#   'pos': [37.3783093, -122.013312],
#   'timestamp': '2011-01-29T17:07:38Z',
#   'type': 'node',
#   'uid': '201724',
#   'user': 'mk408',
#   'version': '10'},
#  {'created': {'changeset': '7124511'},
#   'pos': [37.3781075, -122.0126822],
#   'timestamp': '2011-01-29T17:07:57Z',
#   'type': 'node',
#   'uid': '201724',
#   'user': 'mk408',
#   'version': '8'},
#  {'created': {'changeset': '8231395'},
#   'pos': [37.3310249, -122.014277],
#   'timestamp': '2011-05-23T23:51:48Z',
#   'type': 'node',
#   'uid': '14293',
#   'user': 'KindredCoda',
#   'version': '7'},
#  {'created': {'changeset': '8231395'},
#   'pos': [37.3301069, -122.0142763],
#   'timestamp': '2011-05-23T23:51:48Z',
#   'type': 'node',
#   'uid': '14293',
#   'user': 'KindredCoda',
#   'version': '7'},
#  {'created': {'changeset': '8231395'},
#   'pos': [37.3301566, -122.0143805],
#   'timestamp': '2011-05-23T23:51:48Z',
#   'type': 'node',
#   'uid': '14293',
#   'user': 'KindredCoda',
#   'version': '9'},
#  {'created': {'changeset': '8231395'},
#   'pos': [37.331074, -122.0143738],
#   'timestamp': '2011-05-23T23:51:48Z',
#   'type': 'node',
#   'uid': '14293',
#   'user': 'KindredCoda',
#   'version': '6'},
#  {'created': {'changeset': '18976315'},
#   'highway': 'traffic_signals',
#   'pos': [37.411326, -121.9214216],
#   'timestamp': '2013-11-18T16:24:20Z',
#   'type': 'node',
#   'uid': '28775',
#   'user': 'StellanL',
#   'version': '8'},
#  {'created': {'changeset': '8662772'},
#   'pos': [37.4111461, -121.922809],
#   'timestamp': '2011-07-08T03:56:02Z',
#   'type': 'node',
#   'uid': '14293',
#   'user': 'KindredCoda',
#   'version': '10'},
#  {'created': {'changeset': '8662772'},
#   'pos': [37.411175, -121.9242621],
#   'timestamp': '2011-07-08T03:56:02Z',
#   'type': 'node',
#   'uid': '14293',
#   'user': 'KindredCoda',
#   'version': '8'},
#  {'created': {'changeset': '8662928'},
#   'pos': [37.4135502, -121.9327514],
#   'timestamp': '2011-07-08T05:07:15Z',
#   'type': 'node',
#   'uid': '14293',
#   'user': 'KindredCoda',
#   'version': '7'},
#  {'created': {'changeset': '8662928'},
#   'pos': [37.4122153, -121.9387524],
#   'timestamp': '2011-07-08T05:07:15Z',
#   'type': 'node',
#   'uid': '14293',
#   'user': 'KindredCoda',
#   'version': '7'},
#  {'created': {'changeset': '8662389'},
#   'pos': [37.4079442, -121.9484094],
#   'timestamp': '2011-07-08T00:47:06Z',
#   'type': 'node',
#   'uid': '14293',
#   'user': 'KindredCoda',
#   'version': '10'},
#  {'created': {'changeset': '8662389'},
#   'pos': [37.4113865, -121.9577287],
#   'timestamp': '2011-07-08T00:47:06Z',
#   'type': 'node',
#   'uid': '14293',
#   'user': 'KindredCoda',
#   'version': '10'},
#  {'created': {'changeset': '20308989'},
#   'pos': [37.4088948, -121.9611975],
#   'timestamp': '2014-01-31T22:48:18Z',
#   'type': 'node',
#   'uid': '318696',
#   'user': 'n76',
#   'version': '9'},
#  {'created': {'changeset': '8639940'},
#   'pos': [37.4040536, -121.9722341],
#   'timestamp': '2011-07-05T15:05:59Z',
#   'type': 'node',
#   'uid': '14293',
#   'user': 'KindredCoda',
#   'version': '8'},
#  {'created': {'changeset': '36805771'},
#   'pos': [37.4135559, -121.931822],
#   'timestamp': '2016-01-25T21:32:25Z',
#   'type': 'node',
#   'uid': '1829683',
#   'user': 'Luis36995',
#   'version': '7'},
#  {'created': {'changeset': '8662389'},
#   'pos': [37.4082239, -121.9472341],
#   'timestamp': '2011-07-08T00:47:06Z',
#   'type': 'node',
#   'uid': '14293',
#   'user': 'KindredCoda',
#   'version': '9'},
#  {'created': {'changeset': '32758414'},
#   'pos': [37.4082589, -121.9504997],
#   'timestamp': '2015-07-20T16:57:22Z',
#   'type': 'node',
#   'uid': '152074',
#   'user': 'beweta',
#   'version': '11'},
#  {'created': {'changeset': '8662389'},
#   'pos': [37.4110159, -121.9551869],
#   'timestamp': '2011-07-08T00:47:06Z',
#   'type': 'node',
#   'uid': '14293',
#   'user': 'KindredCoda',
#   'version': '10'},
#  {'created': {'changeset': '8662389'},
#   'pos': [37.4102896, -121.9600712],
#   'timestamp': '2011-07-08T00:47:06Z',
#   'type': 'node',
#   'uid': '14293',
#   'user': 'KindredCoda',
#   'version': '10'},
#  {'created': {'changeset': '8662389'},
#   'pos': [37.4109461, -121.9591554],
#   'timestamp': '2011-07-08T00:47:06Z',
#   'type': 'node',
#   'uid': '14293',
#   'user': 'KindredCoda',
#   'version': '9'},
#  {'created': {'changeset': '8662389'},
#   'pos': [37.4113102, -121.95606],
#   'timestamp': '2011-07-08T00:47:06Z',
#   'type': 'node',
#   'uid': '14293',
#   'user': 'KindredCoda',
#   'version': '10'},
#  {'created': {'changeset': '8639940'},
#   'pos': [37.403633, -121.9744747],
#   'timestamp': '2011-07-05T15:05:55Z',
#   'type': 'node',
#   'uid': '14293',
#   'user': 'KindredCoda',
#   'version': '22'},
#  {'created': {'changeset': '20817845'},
#   'pos': [37.4100627, -122.0121683],
#   'timestamp': '2014-02-27T21:51:07Z',
#   'type': 'node',
#   'uid': '318696',
#   'user': 'n76',
#   'version': '8'},
#  {'created': {'changeset': '33529983'},
#   'pos': [37.4102285, -122.012764],
#   'timestamp': '2015-08-23T18:13:02Z',
#   'type': 'node',
#   'uid': '33757',
#   'user': 'Minh Nguyen',
#   'version': '6'},
#  {'created': {'changeset': '20817845'},
#   'pos': [37.4097873, -122.0121898],
#   'timestamp': '2014-02-27T21:51:07Z',
#   'type': 'node',
#   'uid': '318696',
#   'user': 'n76',
#   'version': '6'},
#  {'created': {'changeset': '33529983'},
#   'pos': [37.4105587, -122.0134668],
#   'timestamp': '2015-08-23T18:13:02Z',
#   'type': 'node',
#   'uid': '33757',
#   'user': 'Minh Nguyen',
#   'version': '7'},
#  {'created': {'changeset': '33529983'},
#   'pos': [37.4093848, -122.0115275],
#   'timestamp': '2015-08-23T18:13:02Z',
#   'type': 'node',
#   'uid': '33757',
#   'user': 'Minh Nguyen',
#   'version': '9'},
#  {'created': {'changeset': '20303686'},
#   'pos': [37.4107557, -122.0134418],
#   'timestamp': '2014-01-31T17:35:22Z',
#   'type': 'node',
#   'uid': '318696',
#   'user': 'n76',
#   'version': '9'},
#  {'created': {'changeset': '28196530'},
#   'pos': [37.4071487, -122.0100412],
#   'timestamp': '2015-01-16T21:38:50Z',
#   'type': 'node',
#   'uid': '28775',
#   'user': 'StellanL',
#   'version': '11'},
#  {'created': {'changeset': '28196530'},
#   'pos': [37.4064319, -122.009778],
#   'timestamp': '2015-01-16T21:38:50Z',
#   'type': 'node',
#   'uid': '28775',
#   'user': 'StellanL',
#   'version': '8'},
#  {'created': {'changeset': '6776772'},
#   'pos': [37.4058265, -122.0097096],
#   'timestamp': '2010-12-27T11:58:25Z',
#   'type': 'node',
#   'uid': '14293',
#   'user': 'KindredCoda',
#   'version': '4'},
#  {'created': {'changeset': '39152547'},
#   'pos': [37.4051223, -122.0098679],
#   'timestamp': '2016-05-06T21:35:40Z',
#   'type': 'node',
#   'uid': '1829683',
#   'user': 'Luis36995',
#   'version': '6'},
#  {'created': {'changeset': '6776772'},
#   'pos': [37.4120221, -121.9863798],
#   'timestamp': '2010-12-27T11:50:18Z',
#   'type': 'node',
#   'uid': '14293',
#   'user': 'KindredCoda',
#   'version': '3'},
#  {'created': {'changeset': '4656002'},
#   'pos': [37.4184089, -121.9706535],
#   'timestamp': '2010-05-10T05:32:12Z',
#   'type': 'node',
#   'uid': '14293',
#   'user': 'KindredCoda',
#   'version': '4'},
#  {'created': {'changeset': '4656002'},
#   'pos': [37.4187136, -121.9688377],
#   'timestamp': '2010-05-10T05:32:12Z',
#   'type': 'node',
#   'uid': '14293',
#   'user': 'KindredCoda',
#   'version': '5'},
#  {'created': {'changeset': '4635988'},
#   'pos': [37.4190842, -121.9598817],
#   'timestamp': '2010-05-08T06:38:33Z',
#   'type': 'node',
#   'uid': '14293',
#   'user': 'KindredCoda',
#   'version': '3'},
#  {'created': {'changeset': '36857647'},
#   'pos': [37.4192941, -121.9544019],
#   'timestamp': '2016-01-28T14:13:15Z',
#   'type': 'node',
#   'uid': '2748195',
#   'user': 'karitotp',
#   'version': '6'},
#  {'created': {'changeset': '34108059'},
#   'exit_to:right': 'Zanker Road',
#   'pos': [37.4192828, -121.9447659],
#   'timestamp': '2015-09-18T17:47:13Z',
#   'type': 'node',
#   'uid': '813769',
#   'user': 'lemba',
#   'version': '9'},
#  {'created': {'changeset': '4656002'},
#   'pos': [37.4194954, -121.9428793],
#   'timestamp': '2010-05-10T05:36:38Z',
#   'type': 'node',
#   'uid': '14293',
#   'user': 'KindredCoda',
#   'version': '3'},
#  {'created': {'changeset': '143716'},
#   'pos': [37.4208015, -121.9372283],
#   'timestamp': '2009-02-04T07:42:57Z',
#   'type': 'node',
#   'uid': '93800',
#   'user': 'Alan Vogt',
#   'version': '3'},
#  {'created': {'changeset': '12114933'},
#   'exit_to': 'McCarthy Boulevard;Cypress Street',
#   'highway': 'motorway_junction',
#   'pos': [37.4220052, -121.9317622],
#   'ref': '9A',
#   'source': 'http://www.dot.ca.gov/hq/traffops/signtech/calnexus/pdf/twothirtyseveneast.pdf;http://www.dot.ca.gov/hq/traffops/signtech/calnexus/pdf/twothirtysevenwest.pdf',
#   'timestamp': '2012-07-04T21:01:01Z',
#   'type': 'node',
#   'uid': '169004',
#   'user': 'oldtopos',
#   'version': '6'},
#  {'created': {'changeset': '6784016'},
#   'pos': [37.4222907, -121.9276692],
#   'timestamp': '2010-12-28T01:02:59Z',
#   'type': 'node',
#   'uid': '14293',
#   'user': 'KindredCoda',
#   'version': '4'},
#  {'created': {'changeset': '6776772'},
#   'pos': [37.4069941, -122.0085026],
#   'timestamp': '2010-12-27T12:04:12Z',
#   'type': 'node',
#   'uid': '14293',
#   'user': 'KindredCoda',
#   'version': '4'},
#  {'created': {'changeset': '6776772'},
#   'pos': [37.4076887, -122.0103748],
#   'timestamp': '2010-12-27T12:03:33Z',
#   'type': 'node',
#   'uid': '14293',
#   'user': 'KindredCoda',
#   'version': '6'},
#  {'created': {'changeset': '29212705'},
#   'pos': [37.3522307, -122.0141119],
#   'timestamp': '2015-03-03T01:43:35Z',
#   'type': 'node',
#   'uid': '202256',
#   'user': 'Telecas',
#   'version': '14'},
#  {'created': {'changeset': '8233100'},
#   'pos': [37.3181582, -121.9896063],
#   'timestamp': '2011-05-24T08:32:23Z',
#   'type': 'node',
#   'uid': '14293',
#   'user': 'KindredCoda',
#   'version': '37'},
#  {'created': {'changeset': '8233100'},
#   'pos': [37.3179412, -121.9871059],
#   'timestamp': '2011-05-24T08:32:23Z',
#   'type': 'node',
#   'uid': '14293',
#   'user': 'KindredCoda',
#   'version': '37'},
#  {'created': {'changeset': '8233296'},
#   'pos': [37.3179706, -121.9810492],
#   'timestamp': '2011-05-24T09:00:13Z',
#   'type': 'node',
#   'uid': '14293',
#   'user': 'KindredCoda',
#   'version': '38'},
#  {'created': {'changeset': '8233296'},
#   'pos': [37.3178538, -121.9781383],
#   'timestamp': '2011-05-24T09:00:13Z',
#   'type': 'node',
#   'uid': '14293',
#   'user': 'KindredCoda',
#   'version': '38'},
#  {'created': {'changeset': '8233296'},
#   'pos': [37.3177225, -121.9771956],
#   'timestamp': '2011-05-24T09:00:13Z',
#   'type': 'node',
#   'uid': '14293',
#   'user': 'KindredCoda',
#   'version': '37'},
#  {'created': {'changeset': '8233296'},
#   'pos': [37.3168983, -121.9744506],
#   'timestamp': '2011-05-24T09:00:13Z',
#   'type': 'node',
#   'uid': '14293',
#   'user': 'KindredCoda',
#   'version': '36'},
#  {'created': {'changeset': '8233296'},
#   'pos': [37.3161752, -121.9700546],
#   'timestamp': '2011-05-24T09:00:13Z',
#   'type': 'node',
#   'uid': '14293',
#   'user': 'KindredCoda',
#   'version': '47'},
#  {'created': {'changeset': '8232841'},
#   'pos': [37.3163012, -121.9657989],
#   'timestamp': '2011-05-24T07:55:03Z',
#   'type': 'node',
#   'uid': '14293',
#   'user': 'KindredCoda',
#   'version': '36'},
#  {'created': {'changeset': '8232841'},
#   'pos': [37.3163648, -121.9567351],
#   'timestamp': '2011-05-24T07:55:03Z',
#   'type': 'node',
#   'uid': '14293',
#   'user': 'KindredCoda',
#   'version': '46'},
#  {'created': {'changeset': '21368423'},
#   'pos': [37.3659758, -121.9961319],
#   'timestamp': '2014-03-28T16:19:54Z',
#   'type': 'node',
#   'uid': '595221',
#   'user': 'matthieun',
#   'version': '8'},
#  {'created': {'changeset': '18479493'},
#   'pos': [37.3543516, -121.9964087],
#   'timestamp': '2013-10-22T02:22:42Z',
#   'type': 'node',
#   'uid': '595221',
#   'user': 'matthieun',
#   'version': '7'},
#  {'created': {'changeset': '18479493'},
#   'pos': [37.353056, -121.996558],
#   'timestamp': '2013-10-22T02:22:42Z',
#   'type': 'node',
#   'uid': '595221',
#   'user': 'matthieun',
#   'version': '7'},
#  {'created': {'changeset': '18479493'},
#   'pos': [37.3517191, -121.996526],
#   'timestamp': '2013-10-22T02:22:43Z',
#   'type': 'node',
#   'uid': '595221',
#   'user': 'matthieun',
#   'version': '4'},
#  {'created': {'changeset': '285175'},
#   'pos': [37.3247434, -121.9406569],
#   'timestamp': '2008-12-09T07:20:54Z',
#   'type': 'node',
#   'uid': '54598',
#   'user': 'adbrown',
#   'version': '30'},
#  {'created': {'changeset': '754183'},
#   'pos': [37.3287781, -121.9407021],
#   'timestamp': '2008-11-16T03:30:59Z',
#   'type': 'node',
#   'uid': '54598',
#   'user': 'adbrown',
#   'version': '25'},
#  {'created': {'changeset': '754183'},
#   'pos': [37.3300748, -121.9405047],
#   'timestamp': '2008-11-16T03:30:59Z',
#   'type': 'node',
#   'uid': '54598',
#   'user': 'adbrown',
#   'version': '27'},
#  {'created': {'changeset': '285175'},
#   'pos': [37.331044, -121.9400498],
#   'timestamp': '2008-12-09T07:30:56Z',
#   'type': 'node',
#   'uid': '54598',
#   'user': 'adbrown',
#   'version': '18'},
#  {'created': {'changeset': '285175'},
#   'pos': [37.3320462, -121.9393265],
#   'timestamp': '2008-12-09T07:30:56Z',
#   'type': 'node',
#   'uid': '54598',
#   'user': 'adbrown',
#   'version': '18'},
#  {'created': {'changeset': '6776772'},
#   'pos': [37.4111572, -121.989475],
#   'timestamp': '2010-12-27T11:52:11Z',
#   'type': 'node',
#   'uid': '14293',
#   'user': 'KindredCoda',
#   'version': '2'},
#  {'created': {'changeset': '13451361'},
#   'exit_to': 'Great America Parkway;Lafayette Street',
#   'highway': 'motorway_junction',
#   'pos': [37.4130124, -121.9836706],
#   'ref': '6',
#   'source': 'http://www.dot.ca.gov/hq/traffops/signtech/calnexus/pdf/twothirtyseveneast.pdf;http://www.dot.ca.gov/hq/traffops/signtech/calnexus/pdf/twothirtysevenwest.pdf',
#   'timestamp': '2012-10-11T08:35:50Z',
#   'type': 'node',
#   'uid': '207745',
#   'user': 'NE2',
#   'version': '6'},
#  {'created': {'changeset': '4656002'},
#   'pos': [37.4182726, -121.9711149],
#   'timestamp': '2010-05-10T05:32:30Z',
#   'type': 'node',
#   'uid': '14293',
#   'user': 'KindredCoda',
#   'version': '3'},
#  {'created': {'changeset': '20527489'},
#   'pos': [37.4187388, -121.9684543],
#   'timestamp': '2014-02-12T20:13:10Z',
#   'type': 'node',
#   'uid': '634020',
#   'user': 'user_634020',
#   'version': '6'},
#  {'created': {'changeset': '36857647'},
#   'pos': [37.4190306, -121.9605352],
#   'timestamp': '2016-01-28T14:13:15Z',
#   'type': 'node',
#   'uid': '2748195',
#   'user': 'karitotp',
#   'version': '4'},
#  {'created': {'changeset': '33478830'},
#   'pos': [37.3972189, -121.9362932],
#   'timestamp': '2015-08-21T09:20:58Z',
#   'type': 'node',
#   'uid': '1306',
#   'user': 'PlaneMad',
#   'version': '17'},
#  {'created': {'changeset': '36939372'},
#   'highway': 'traffic_signals',
#   'pos': [37.3868647, -121.9607225],
#   'timestamp': '2016-02-01T15:45:18Z',
#   'type': 'node',
#   'uid': '2748195',
#   'user': 'karitotp',
#   'version': '9'},
#  {'created': {'changeset': '33478728'},
#   'pos': [37.3896127, -121.9547195],
#   'timestamp': '2015-08-21T09:15:37Z',
#   'type': 'node',
#   'uid': '1306',
#   'user': 'PlaneMad',
#   'version': '6'},
#  {'created': {'changeset': '36939372'},
#   'pos': [37.3849654, -121.9625227],
#   'timestamp': '2016-02-01T15:45:18Z',
#   'type': 'node',
#   'uid': '2748195',
#   'user': 'karitotp',
#   'version': '7'},
#  {'created': {'changeset': '39148849'},
#   'pos': [37.3940245, -121.9444795],
#   'timestamp': '2016-05-06T17:23:42Z',
#   'type': 'node',
#   'uid': '2226712',
#   'user': 'dannykath',
#   'version': '16'},
#  {'created': {'changeset': '36844837'},
#   'pos': [37.377206, -121.96595],
#   'timestamp': '2016-01-27T20:18:49Z',
#   'type': 'node',
#   'uid': '1829683',
#   'user': 'Luis36995',
#   'version': '20'},
#  {'created': {'changeset': '794494'},
#   'pos': [37.3666053, -121.9652998],
#   'timestamp': '2009-03-12T01:19:36Z',
#   'type': 'node',
#   'uid': '100744',
#   'user': 'fennecfoxen',
#   'version': '19'},
#  {'created': {'changeset': '803335'},
#   'pos': [37.3654048, -121.9654722],
#   'timestamp': '2009-03-13T00:43:07Z',
#   'type': 'node',
#   'uid': '100744',
#   'user': 'fennecfoxen',
#   'version': '19'},
#  {'created': {'changeset': '7042221'},
#   'pos': [37.3642358, -121.9662025],
#   'timestamp': '2011-01-21T17:00:36Z',
#   'type': 'node',
#   'uid': '201724',
#   'user': 'mk408',
#   'version': '19'},
#  {'created': {'changeset': '7042221'},
#   'pos': [37.3634994, -121.9668485],
#   'timestamp': '2011-01-21T17:00:35Z',
#   'type': 'node',
#   'uid': '201724',
#   'user': 'mk408',
#   'version': '20'},
#  {'created': {'changeset': '6887244'},
#   'pos': [37.3662599, -121.9207606],
#   'timestamp': '2011-01-06T21:31:57Z',
#   'type': 'node',
#   'uid': '14293',
#   'user': 'KindredCoda',
#   'version': '10'},
#  {'created': {'changeset': '6887193'},
#   'pos': [37.370596, -121.9266502],
#   'timestamp': '2011-01-06T21:17:58Z',
#   'type': 'node',
#   'uid': '14293',
#   'user': 'KindredCoda',
#   'version': '11'},
#  {'created': {'changeset': '13422450'},
#   'exit_to:left': 'US-101 North',
#   'exit_to:right': 'North First Street',
#   'highway': 'motorway_junction',
#   'pos': [37.3719432, -121.9270579],
#   'ref': '9A',
#   'ref:left': '9B',
#   'ref:right': '9A',
#   'source': 'http://www.dot.ca.gov/hq/traffops/signtech/calnexus/pdf/87.pdf',
#   'timestamp': '2012-10-09T06:59:58Z',
#   'type': 'node',
#   'uid': '207745',
#   'user': 'NE2',
#   'version': '15'},
#  {'created': {'changeset': '749969'},
#   'pos': [37.3693378, -121.9256138],
#   'timestamp': '2008-11-15T09:27:04Z',
#   'type': 'node',
#   'uid': '54598',
#   'user': 'adbrown',
#   'version': '9'},
#  {'created': {'changeset': '763986'},
#   'pos': [37.3868269, -121.9764773],
#   'timestamp': '2008-11-18T07:45:18Z',
#   'type': 'node',
#   'uid': '54598',
#   'user': 'adbrown',
#   'version': '7'},
#  {'created': {'changeset': '43969977'},
#   'highway': 'motorway_junction',
#   'pos': [37.3844774, -121.9720299],
#   'ref': '393',
#   'source': 'http://www.dot.ca.gov/hq/traffops/signtech/calnexus/pdf/101.pdf',
#   'timestamp': '2016-11-26T19:23:25Z',
#   'type': 'node',
#   'uid': '1751737',
#   'user': 'Skybunny',
#   'version': '30'},
#  {'created': {'changeset': '24413610'},
#   'pos': [37.3850734, -121.9735955],
#   'timestamp': '2014-07-29T01:42:45Z',
#   'type': 'node',
#   'uid': '28775',
#   'user': 'StellanL',
#   'version': '4'},
#  {'created': {'changeset': '36843881'},
#   'pos': [37.3865161, -121.9753937],
#   'timestamp': '2016-01-27T19:28:19Z',
#   'type': 'node',
#   'uid': '1829683',
#   'user': 'Luis36995',
#   'version': '7'},
#  {'created': {'changeset': '36843881'},
#   'pos': [37.3835841, -121.9777424],
#   'timestamp': '2016-01-27T19:28:19Z',
#   'type': 'node',
#   'uid': '1829683',
#   'user': 'Luis36995',
#   'version': '10'},
#  {'created': {'changeset': '18031128'},
#   'pos': [37.3759923, -121.9778431],
#   'timestamp': '2013-09-25T16:49:07Z',
#   'type': 'node',
#   'uid': '318696',
#   'user': 'n76',
#   'version': '12'},
#  {'created': {'changeset': '24413610'},
#   'pos': [37.3839841, -121.9776132],
#   'timestamp': '2014-07-29T01:42:45Z',
#   'type': 'node',
#   'uid': '28775',
#   'user': 'StellanL',
#   'version': '5'},
#  {'created': {'changeset': '39218618'},
#   'highway': 'traffic_signals',
#   'pos': [37.3741456, -121.9778483],
#   'timestamp': '2016-05-10T14:26:25Z',
#   'type': 'node',
#   'uid': '1829683',
#   'user': 'Luis36995',
#   'version': '11'},
#  {'created': {'changeset': '24413610'},
#   'pos': [37.3860681, -121.9767824],
#   'timestamp': '2014-07-29T01:42:45Z',
#   'type': 'node',
#   'uid': '28775',
#   'user': 'StellanL',
#   'version': '8'},
#  {'created': {'changeset': '12135372'},
#   'exit_to': 'Fair Oaks Avenue',
#   'highway': 'motorway_junction',
#   'pos': [37.3949788, -122.0092224],
#   'ref': '395',
#   'timestamp': '2012-07-06T22:08:21Z',
#   'type': 'node',
#   'uid': '169004',
#   'user': 'oldtopos',
#   'version': '28'},
#  {'created': {'changeset': '7124511'},
#   'pos': [37.3788126, -122.013463],
#   'timestamp': '2011-01-29T17:07:34Z',
#   'type': 'node',
#   'uid': '201724',
#   'user': 'mk408',
#   'version': '4'},
#  {'created': {'changeset': '32109704'},
#   'crossing': 'zebra',
#   'highway': 'crossing',
#   'pos': [37.3518171, -121.9372117],
#   'timestamp': '2015-06-21T05:07:49Z',
#   'type': 'node',
#   'uid': '33757',
#   'user': 'Minh Nguyen',
#   'version': '19'},
#  {'created': {'changeset': '32109704'},
#   'crossing': 'zebra',
#   'highway': 'crossing',
#   'pos': [37.3522077, -121.9373629],
#   'timestamp': '2015-06-21T05:07:49Z',
#   'type': 'node',
#   'uid': '33757',
#   'user': 'Minh Nguyen',
#   'version': '22'},
#  {'created': {'changeset': '36845828'},
#   'pos': [37.3935878, -121.920923],
#   'timestamp': '2016-01-27T21:06:12Z',
#   'type': 'node',
#   'uid': '1829683',
#   'user': 'Luis36995',
#   'version': '14'},
#  {'created': {'changeset': '794494'},
#   'pos': [37.3939207, -121.9215605],
#   'timestamp': '2009-03-12T01:19:59Z',
#   'type': 'node',
#   'uid': '100744',
#   'user': 'fennecfoxen',
#   'version': '12'},
#  {'created': {'changeset': '794494'},
#   'pos': [37.394323, -121.9220326],
#   'timestamp': '2009-03-12T01:19:59Z',
# ...
#   'uid': '1376118',
#   'user': 'ChrisZontine',
#   'version': '7'},
#  {'created': {'changeset': '15169276'},
#   'pos': [37.3584615, -122.0085356],
#   'timestamp': '2013-02-26T05:08:22Z',
#   'type': 'node',
#   'uid': '74705',
#   'user': 'Bike Mapper',
#   'version': '4'},
#  {'created': {'changeset': '15169276'},
#   'pos': [37.3584639, -122.0076473],
#   'timestamp': '2013-02-26T05:08:22Z',
#   'type': 'node',
#   'uid': '74705',
#   'user': 'Bike Mapper',
#   'version': '4'},
#  {'created': {'changeset': '3424990'},
#   'pos': [37.3585233, -122.0058464],
#   'timestamp': '2009-12-22T06:37:34Z',
#   'type': 'node',
#   'uid': '147510',
#   'user': 'woodpeck_fixbot',
#   'version': '4'},
#  {'created': {'changeset': '3424990'},
#   'pos': [37.3586256, -122.0050139],
#   'timestamp': '2009-12-22T06:37:34Z',
#   'type': 'node',
#   'uid': '147510',
#   'user': 'woodpeck_fixbot',
#   'version': '4'},
#  {'created': {'changeset': '36844205'},
#   'highway': 'traffic_signals',
#   'pos': [37.3805786, -121.9958116],
#   'timestamp': '2016-01-27T19:44:39Z',
#   'type': 'node',
#   'uid': '1829683',
#   'user': 'Luis36995',
#   'version': '12'},
#  {'created': {'changeset': '20725079'},
#   'highway': 'traffic_signals',
#   'pos': [37.380546, -121.9933995],
#   'timestamp': '2014-02-23T01:42:00Z',
#   'type': 'node',
#   'uid': '169004',
#   'user': 'oldtopos',
#   'version': '8'},
#  {'created': {'changeset': '39218388'},
#   'pos': [37.3805853, -121.9879493],
#   'timestamp': '2016-05-10T14:18:37Z',
#   'type': 'node',
#   'uid': '1829683',
#   'user': 'Luis36995',
#   'version': '12'},
#  {'created': {'changeset': '24413610'},
#   'pos': [37.3809989, -122.0136849],
#   'timestamp': '2014-07-29T01:42:46Z',
#   'type': 'node',
#   'uid': '28775',
#   'user': 'StellanL',
#   'version': '8'},
#  {'created': {'changeset': '21369101'},
#   'highway': 'traffic_signals',
#   'pos': [37.3809795, -122.012044],
#   'timestamp': '2014-03-28T17:00:48Z',
#   'type': 'node',
#   'uid': '595221',
#   'user': 'matthieun',
#   'version': '12'},
#  {'created': {'changeset': '24413610'},
#   'pos': [37.3809547, -122.0102963],
#   'timestamp': '2014-07-29T01:42:46Z',
#   'type': 'node',
#   'uid': '28775',
#   'user': 'StellanL',
#   'version': '9'},
#  {'created': {'changeset': '12563617'},
#   'highway': 'traffic_signals',
#   'pos': [37.3809159, -122.0073421],
#   'timestamp': '2012-07-31T16:27:30Z',
#   'type': 'node',
#   'uid': '169004',
#   'user': 'oldtopos',
#   'version': '9'},
#  {'created': {'changeset': '4949992'},
#   'pos': [37.3808704, -122.0057526],
#   'timestamp': '2010-06-09T22:20:56Z',
#   'type': 'node',
#   'uid': '296587',
#   'user': 'bmhr',
#   'version': '6'},
#  {'created': {'changeset': '4949992'},
#   'pos': [37.3805157, -122.0030575],
#   'timestamp': '2010-06-09T22:20:56Z',
#   'type': 'node',
#   'uid': '296587',
#   'user': 'bmhr',
#   'version': '7'},
#  {'created': {'changeset': '13757040'},
#   'highway': 'traffic_signals',
#   'pos': [37.380489, -122.0009834],
#   'timestamp': '2012-11-05T06:33:47Z',
#   'type': 'node',
#   'uid': '47892',
#   'user': 'richlv',
#   'version': '11'},
#  {'created': {'changeset': '8735092'},
#   'pos': [37.4032559, -121.9925268],
#   'timestamp': '2011-07-15T21:51:52Z',
#   'type': 'node',
#   'uid': '14293',
#   'user': 'KindredCoda',
#   'version': '8'},
#  {'created': {'changeset': '18985848'},
#   'pos': [37.4063534, -121.9925363],
#   'timestamp': '2013-11-19T00:29:10Z',
#   'type': 'node',
#   'uid': '28775',
#   'user': 'StellanL',
#   'version': '8'},
#  {'created': {'changeset': '3424990'},
#   'pos': [37.3298813, -122.0033062],
#   'timestamp': '2009-12-22T06:37:44Z',
#   'type': 'node',
#   'uid': '147510',
#   'user': 'woodpeck_fixbot',
#   'version': '4'},
#  {'created': {'changeset': '3424990'},
#   'pos': [37.3304, -122.003744],
#   'timestamp': '2009-12-22T06:37:44Z',
#   'type': 'node',
#   'uid': '147510',
#   'user': 'woodpeck_fixbot',
#   'version': '3'},
#  {'created': {'changeset': '3424990'},
#   'pos': [37.3303318, -121.9999932],
#   'timestamp': '2009-12-22T06:37:44Z',
#   'type': 'node',
#   'uid': '147510',
#   'user': 'woodpeck_fixbot',
#   'version': '3'},
#  {'created': {'changeset': '3424990'},
#   'pos': [37.3303181, -122.0010489],
#   'timestamp': '2009-12-22T06:37:45Z',
#   'type': 'node',
#   'uid': '147510',
#   'user': 'woodpeck_fixbot',
#   'version': '3'},
#  {'created': {'changeset': '3424990'},
#   'pos': [37.3300383, -122.0019415],
#   'timestamp': '2009-12-22T06:37:45Z',
#   'type': 'node',
#   'uid': '147510',
#   'user': 'woodpeck_fixbot',
#   'version': '4'},
#  {'created': {'changeset': '3424990'},
#   'pos': [37.329895, -122.0026368],
#   'timestamp': '2009-12-22T06:37:45Z',
#   'type': 'node',
#   'uid': '147510',
#   'user': 'woodpeck_fixbot',
#   'version': '4'},
#  {'created': {'changeset': '5056619'},
#   'pos': [37.3850692, -121.9499848],
#   'timestamp': '2010-06-23T06:51:20Z',
#   'type': 'node',
#   'uid': '28775',
#   'user': 'StellanL',
#   'version': '5'},
#  {'created': {'changeset': '15308618'},
#   'pos': [37.3861214, -121.9507434],
#   'timestamp': '2013-03-09T22:36:45Z',
#   'type': 'node',
#   'uid': '74705',
#   'user': 'Bike Mapper',
#   'version': '6'},
#  {'created': {'changeset': '3424990'},
#   'pos': [37.416831, -121.9629766],
#   'timestamp': '2009-12-22T06:37:50Z',
#   'type': 'node',
#   'uid': '147510',
#   'user': 'woodpeck_fixbot',
#   'version': '4'},
#  {'created': {'changeset': '18985848'},
#   'pos': [37.4157365, -121.9641091],
#   'timestamp': '2013-11-19T00:29:10Z',
#   'type': 'node',
#   'uid': '28775',
#   'user': 'StellanL',
#   'version': '5'},
#  {'created': {'changeset': '36689632'},
#   'highway': 'traffic_signals',
#   'pos': [37.3378774, -121.9826091],
#   'timestamp': '2016-01-19T22:09:37Z',
#   'traffic_signals': 'signal',
#   'type': 'node',
#   'uid': '2655992',
#   'user': 'steverumizen',
#   'version': '7'},
#  {'created': {'changeset': '25307829'},
#   'pos': [37.3388292, -121.9828628],
#   'timestamp': '2014-09-08T13:47:47Z',
#   'type': 'node',
#   'uid': '1110270',
#   'user': 'afdreher',
#   'version': '5'},
#  {'created': {'changeset': '3424990'},
#   'pos': [37.3400415, -121.982772],
#   'timestamp': '2009-12-22T06:37:51Z',
#   'type': 'node',
#   'uid': '147510',
#   'user': 'woodpeck_fixbot',
#   'version': '4'},
#  {'created': {'changeset': '25307829'},
#   'pos': [37.3406887, -121.9828092],
#   'timestamp': '2014-09-08T13:47:47Z',
#   'type': 'node',
#   'uid': '1110270',
#   'user': 'afdreher',
#   'version': '6'},
#  {'created': {'changeset': '25307829'},
#   'pos': [37.3418616, -121.9825034],
#   'timestamp': '2014-09-08T13:47:47Z',
#   'type': 'node',
#   'uid': '1110270',
#   'user': 'afdreher',
#   'version': '4'},
#  {'created': {'changeset': '25307829'},
#   'pos': [37.3427934, -121.9822567],
#   'timestamp': '2014-09-08T13:47:47Z',
#   'type': 'node',
#   'uid': '1110270',
#   'user': 'afdreher',
#   'version': '4'},
#  {'created': {'changeset': '3424990'},
#   'pos': [37.342853, -121.9822741],
#   'timestamp': '2009-12-22T06:37:51Z',
#   'type': 'node',
#   'uid': '147510',
#   'user': 'woodpeck_fixbot',
#   'version': '3'},
#  {'created': {'changeset': '16393734'},
#   'pos': [37.4133221, -121.960468],
#   'timestamp': '2013-06-02T16:40:41Z',
#   'type': 'node',
#   'uid': '74705',
#   'user': 'Bike Mapper',
#   'version': '7'},
#  {'created': {'changeset': '16393734'},
#   'pos': [37.4134818, -121.9602776],
#   'timestamp': '2013-06-02T16:40:41Z',
#   'type': 'node',
#   'uid': '74705',
#   'user': 'Bike Mapper',
#   'version': '5'},
#  {'created': {'changeset': '3424990'},
#   'pos': [37.4135418, -121.959927],
#   'timestamp': '2009-12-22T06:37:54Z',
#   'type': 'node',
#   'uid': '147510',
#   'user': 'woodpeck_fixbot',
#   'version': '3'},
#  {'created': {'changeset': '16393734'},
#   'pos': [37.4135585, -121.9591899],
#   'timestamp': '2013-06-02T16:40:41Z',
#   'type': 'node',
#   'uid': '74705',
#   'user': 'Bike Mapper',
#   'version': '5'},
#  {'created': {'changeset': '16393734'},
#   'pos': [37.4135798, -121.9586736],
#   'timestamp': '2013-06-02T16:40:41Z',
#   'type': 'node',
#   'uid': '74705',
#   'user': 'Bike Mapper',
#   'version': '4'},
#  {'created': {'changeset': '16393734'},
#   'pos': [37.4135021, -121.9584389],
#   'timestamp': '2013-06-02T16:40:41Z',
#   'type': 'node',
#   'uid': '74705',
#   'user': 'Bike Mapper',
#   'version': '4'},
#  {'created': {'changeset': '3424990'},
#   'pos': [37.4133883, -121.9582388],
#   'timestamp': '2009-12-22T06:37:54Z',
#   'type': 'node',
#   'uid': '147510',
#   'user': 'woodpeck_fixbot',
#   'version': '5'},
#  {'created': {'changeset': '9044962'},
#   'pos': [37.3527093, -122.0080619],
#   'timestamp': '2011-08-17T08:21:28Z',
#   'type': 'node',
#   'uid': '14293',
#   'user': 'KindredCoda',
#   'version': '5'},
#  {'created': {'changeset': '3424990'},
#   'pos': [37.352712, -122.0087107],
#   'timestamp': '2009-12-22T06:37:56Z',
#   'type': 'node',
#   'uid': '147510',
#   'user': 'woodpeck_fixbot',
#   'version': '3'},
#  {'created': {'changeset': '33234842'},
#   'pos': [37.36257, -121.9887255],
#   'timestamp': '2015-08-10T09:37:50Z',
#   'type': 'node',
#   'uid': '2859289',
#   'user': 'Alps Pierrat',
#   'version': '7'},
#  {'created': {'changeset': '3424990'},
#   'pos': [37.3625557, -121.9909847],
#   'timestamp': '2009-12-22T06:37:57Z',
#   'type': 'node',
#   'uid': '147510',
#   'user': 'woodpeck_fixbot',
#   'version': '4'},
#  {'created': {'changeset': '33406539'},
#   'pos': [37.3181114, -121.942184],
#   'timestamp': '2015-08-18T03:54:37Z',
#   'type': 'node',
#   'uid': '33757',
#   'user': 'Minh Nguyen',
#   'version': '4'},
#  {'created': {'changeset': '2251743'},
#   'pos': [37.3175737, -121.9433122],
#   'timestamp': '2009-08-25T04:24:15Z',
#   'type': 'node',
#   'uid': '25510',
#   'user': 'Apo42',
#   'version': '3'},
#  {'created': {'changeset': '14642046'},
#   'pos': [37.317238, -121.9455962],
#   'timestamp': '2013-01-13T22:22:36Z',
#   'type': 'node',
#   'uid': '74705',
#   'user': 'Bike Mapper',
#   'version': '5'},
#  {'created': {'changeset': '2251743'},
#   'pos': [37.3170994, -121.9469721],
#   'timestamp': '2009-08-25T04:24:16Z',
#   'type': 'node',
#   'uid': '25510',
#   'user': 'Apo42',
#   'version': '4'},
#  {'created': {'changeset': '3424990'},
#   'pos': [37.3632373, -121.9996494],
#   'timestamp': '2009-12-22T06:38:00Z',
#   'type': 'node',
#   'uid': '147510',
#   'user': 'woodpeck_fixbot',
#   'version': '4'},
#  {'created': {'changeset': '3424990'},
#   'highway': 'turning_circle',
#   'pos': [37.363251, -122.0003275],
#   'timestamp': '2009-12-22T06:38:00Z',
#   'type': 'node',
#   'uid': '147510',
#   'user': 'woodpeck_fixbot',
#   'version': '4'},
#  {'created': {'changeset': '3424990'},
#   'pos': [37.3626165, -122.0003532],
#   'timestamp': '2009-12-22T06:38:00Z',
#   'type': 'node',
#   'uid': '147510',
#   'user': 'woodpeck_fixbot',
#   'version': '3'},
#  {'created': {'changeset': '4121084'},
#   'pos': [37.3229654, -122.0054175],
#   'timestamp': '2010-03-14T05:05:27Z',
#   'type': 'node',
#   'uid': '201724',
#   'user': 'mk408',
#   'version': '8'},
#  {'created': {'changeset': '3424990'},
#   'pos': [37.3194735, -122.0054247],
#   'timestamp': '2009-12-22T06:38:03Z',
#   'type': 'node',
#   'uid': '147510',
#   'user': 'woodpeck_fixbot',
#   'version': '5'},
#  {'created': {'changeset': '31986757'},
#   'pos': [37.316454, -122.0053906],
#   'timestamp': '2015-06-15T15:43:16Z',
#   'type': 'node',
#   'uid': '701297',
#   'user': 'erjiang',
#   'version': '4'},
#  {'created': {'changeset': '3951600'},
#   'pos': [37.3262995, -121.9336575],
#   'timestamp': '2010-02-23T09:29:17Z',
#   'type': 'node',
#   'uid': '201724',
#   'user': 'mk408',
#   'version': '4'},
#  {'created': {'changeset': '3951600'},
#   'pos': [37.326313, -121.9359698],
#   'timestamp': '2010-02-23T09:29:17Z',
#   'type': 'node',
#   'uid': '201724',
#   'user': 'mk408',
#   'version': '4'},
#  {'created': {'changeset': '17966256'},
#   'pos': [37.3374771, -121.9761793],
#   'timestamp': '2013-09-22T01:13:09Z',
#   'type': 'node',
#   'uid': '74705',
#   'user': 'Bike Mapper',
#   'version': '7'},
#  {'created': {'changeset': '17966256'},
#   'pos': [37.3371348, -121.9771275],
#   'timestamp': '2013-09-22T01:13:10Z',
#   'type': 'node',
#   'uid': '74705',
#   'user': 'Bike Mapper',
#   'version': '4'},
#  {'created': {'changeset': '3424990'},
#   'pos': [37.3645899, -122.0078346],
#   'timestamp': '2009-12-22T06:38:09Z',
#   'type': 'node',
#   'uid': '147510',
#   'user': 'woodpeck_fixbot',
#   'version': '4'},
#  {'created': {'changeset': '18301166'},
#   'pos': [37.3646456, -122.008718],
#   'timestamp': '2013-10-11T17:01:15Z',
#   'type': 'node',
#   'uid': '1376118',
#   'user': 'ChrisZontine',
#   'version': '5'},
#  {'created': {'changeset': '3424990'},
#   'pos': [37.3806761, -121.9823539],
#   'timestamp': '2009-12-22T06:38:17Z',
#   'type': 'node',
#   'uid': '147510',
#   'user': 'woodpeck_fixbot',
#   'version': '8'},
#  {'created': {'changeset': '3424990'},
#   'pos': [37.3803623, -121.9823453],
#   'timestamp': '2009-12-22T06:38:17Z',
#   'type': 'node',
#   'uid': '147510',
#   'user': 'woodpeck_fixbot',
#   'version': '5'},
#  {'created': {'changeset': '3424990'},
#   'pos': [37.37975, -121.9823137],
#   'timestamp': '2009-12-22T06:38:17Z',
#   'type': 'node',
#   'uid': '147510',
#   'user': 'woodpeck_fixbot',
#   'version': '4'},
#  {'created': {'changeset': '3424990'},
#   'pos': [37.379537, -121.9822531],
#   'timestamp': '2009-12-22T06:38:18Z',
#   'type': 'node',
#   'uid': '147510',
#   'user': 'woodpeck_fixbot',
#   'version': '4'},
#  {'created': {'changeset': '13757555'},
#   'pos': [37.3792079, -121.9821382],
#   'timestamp': '2012-11-05T08:12:15Z',
#   'type': 'node',
#   'uid': '47892',
#   'user': 'richlv',
#   'version': '5'},
#  {'created': {'changeset': '22871042'},
#   'pos': [37.3782068, -121.9818683],
#   'timestamp': '2014-06-11T13:03:40Z',
#   'type': 'node',
#   'uid': '1802220',
#   'user': 'jonesydesign',
#   'version': '7'},
#  {'created': {'changeset': '3424990'},
#   'pos': [37.3778293, -121.9822152],
#   'timestamp': '2009-12-22T06:38:18Z',
#   'type': 'node',
#   'uid': '147510',
#   'user': 'woodpeck_fixbot',
#   'version': '6'},
#  {'created': {'changeset': '36938755'},
#   'pos': [37.3776558, -121.9819614],
#   'timestamp': '2016-02-01T15:15:44Z',
#   'type': 'node',
#   'uid': '2748195',
#   'user': 'karitotp',
#   'version': '8'},
#  {'created': {'changeset': '21608891'},
#   'pos': [37.3758218, -121.9802726],
#   'timestamp': '2014-04-10T14:46:49Z',
#   'type': 'node',
#   'uid': '595221',
#   'user': 'matthieun',
#   'version': '7'},
#  {'created': {'changeset': '3424990'},
#   'pos': [37.415338, -121.9427307],
#   'timestamp': '2009-12-22T06:38:18Z',
#   'type': 'node',
#   'uid': '147510',
#   'user': 'woodpeck_fixbot',
#   'version': '7'},
#  {'created': {'changeset': '3424990'},
#   'pos': [37.4150176, -121.9408596],
#   'timestamp': '2009-12-22T06:38:18Z',
#   'type': 'node',
#   'uid': '147510',
#   'user': 'woodpeck_fixbot',
#   'version': '4'},
#  {'created': {'changeset': '3424990'},
#   'pos': [37.4156516, -121.9402931],
#   'timestamp': '2009-12-22T06:38:18Z',
#   'type': 'node',
#   'uid': '147510',
#   'user': 'woodpeck_fixbot',
#   'version': '4'},
#  {'created': {'changeset': '3424990'},
#   'pos': [37.4159379, -121.9407566],
#   'timestamp': '2009-12-22T06:38:18Z',
#   'type': 'node',
#   'uid': '147510',
#   'user': 'woodpeck_fixbot',
#   'version': '4'},
#  {'created': {'changeset': '8639940'},
#   'pos': [37.3943682, -121.9658108],
#   'timestamp': '2011-07-05T15:05:59Z',
#   'type': 'node',
#   'uid': '14293',
#   'user': 'KindredCoda',
#   'version': '6'},
#  {'created': {'changeset': '8639940'},
#   'pos': [37.3946009, -121.9655829],
#   'timestamp': '2011-07-05T15:05:59Z',
#   'type': 'node',
#   'uid': '14293',
#   'user': 'KindredCoda',
#   'version': '5'},
#  {'created': {'changeset': '2251743'},
#   'pos': [37.3232623, -121.9375155],
#   'timestamp': '2009-08-25T04:24:25Z',
#   'type': 'node',
#   'uid': '25510',
#   'user': 'Apo42',
#   'version': '8'},
#  {'created': {'changeset': '14656037'},
#   'pos': [37.322555, -121.9375294],
#   'timestamp': '2013-01-15T01:42:57Z',
#   'type': 'node',
#   'uid': '74705',
#   'user': 'Bike Mapper',
#   'version': '5'},
#  {'created': {'changeset': '30201824'},
#   'pos': [37.3198378, -121.9374978],
#   'timestamp': '2015-04-14T00:34:43Z',
#   'type': 'node',
#   'uid': '28775',
#   'user': 'StellanL',
#   'version': '7'},
#  {'created': {'changeset': '4140781'},
#   'pos': [37.3378914, -121.9800251],
#   'timestamp': '2010-03-16T05:53:30Z',
#   'type': 'node',
#   'uid': '201724',
#   'user': 'mk408',
#   'version': '5'},
#  {'created': {'changeset': '3930298'},
#   'pos': [37.337037, -121.9800115],
#   'timestamp': '2010-02-21T07:15:26Z',
#   'type': 'node',
#   'uid': '201724',
#   'user': 'mk408',
#   'version': '4'},
#  ...]

# %%
data = process_map(sc_data)

# %%
client = MongoClient()
db = client.SantaClaraOSM
collection = db.santaclaraMAP
collection.insert(data)

# %%
collection
# Out:
# Collection(Database(MongoClient(host=['localhost:27017'], document_class=dict, tz_aware=False, connect=True), u'SantaClaraOSM'), u'santaclaraMAP')

# %% [markdown]
# **File Sizes**

# %%
import os
print 'The original OSM file is {} MB'.format(os.path.getsize(sc_data)/1.0e6) # convert from bytes to megabytes
print 'The JSON file is {} MB'.format(os.path.getsize(sc_data + ".json")/1.0e6) # convert from bytes to megabytes
# Out:
# The original OSM file is 58.944542 MB
# The JSON file is 61.66255 MB

# %% [markdown]
# # 4. insights through MongoDB

# %% [markdown]
# **Number of documents**

# %%
collection.find().count()
# Out:
# 302394

# %% [markdown]
# ** Number of Unique Users **

# %%
# Number of unique users
len(collection.distinct('user'))
# Out:
# 534

# %% [markdown]
# **Number of nodes**

# %%
# Number of nodes
collection.find({"type":"node"}).count()
# Out:
# 263052

# %% [markdown]
# **Number of ways**

# %%
# Number of ways
collection.find({"type":"way"}).count()
# Out:
# 39339

# %% [markdown]
# ** Top 5 contributers **

# %%
result = collection.aggregate( [     { "$group" : {"_id" : "$user", 
                                        "count" : { "$sum" : 1} } },
                                        { "$sort" : {"count" : -1} }, 
                                        { "$limit" : 5 } ] )

print(list(result))
# Out:
# [{u'count': 58912, u'_id': u'samely'}, {u'count': 34481, u'_id': u'dannykath'}, {u'count': 23884, u'_id': u'RichRico'}, {u'count': 17966, u'_id': u'karitotp'}, {u'count': 15622, u'_id': u'matthieun'}]

# %% [markdown]
# ** Top 10 amenities in Santa Clara **

# %%
amenity = collection.aggregate([{'$match': {'amenity': {'$exists': 1}}}, \
                                {'$group': {'_id': '$amenity', \
                                            'count': {'$sum': 1}}}, \
                                {'$sort': {'count': -1}}, \
                                {'$limit': 10}])
print(list(amenity))
# Out:
# [{u'count': 354, u'_id': u'parking'}, {u'count': 237, u'_id': u'restaurant'}, {u'count': 113, u'_id': u'fast_food'}, {u'count': 71, u'_id': u'school'}, {u'count': 61, u'_id': u'cafe'}, {u'count': 58, u'_id': u'place_of_worship'}, {u'count': 48, u'_id': u'fuel'}, {u'count': 42, u'_id': u'parking_entrance'}, {u'count': 31, u'_id': u'toilets'}, {u'count': 27, u'_id': u'bench'}]

# %% [markdown]
# ** Top 10 cuisines in Santa Clara**

# %%
cuisine = collection.aggregate([{"$match":{"amenity":{"$exists":1},
                                 "amenity":"restaurant",}},      
                      {"$group":{"_id":{"Food":"$cuisine"},
                                 "count":{"$sum":1}}},
                      {"$project":{"_id":0,
                                  "Food":"$_id.Food",
                                  "Count":"$count"}},
                      {"$sort":{"Count":-1}}, 
                      {"$limit":10}])
print(list(cuisine))
# Out:
# [{u'Food': None, u'Count': 77}, {u'Food': u'mexican', u'Count': 17}, {u'Food': u'pizza', u'Count': 15}, {u'Food': u'indian', u'Count': 15}, {u'Food': u'chinese', u'Count': 11}, {u'Food': u'sandwich', u'Count': 9}, {u'Food': u'sushi', u'Count': 9}, {u'Food': u'thai', u'Count': 8}, {u'Food': u'american', u'Count': 8}, {u'Food': u'japanese', u'Count': 8}]

# %% [markdown]
# ** Universities in Santa Clara **

# %%
universities = collection.aggregate([{"$match":{"amenity":{"$exists":1}, "amenity": "university", "name":{"$exists":1}}},
                                    {"$group":{"_id":"$name", "count":{"$sum":1}}},
                                    {"$sort":{"count":-1}}])

print(list(universities))
# Out:
# [{u'count': 1, u'_id': u'Bay Area Campus'}, {u'count': 1, u'_id': u'Santa Clara University'}, {u'count': 1, u'_id': u'Medical Center - University of E-W Medicine'}, {u'count': 1, u'_id': u'Nine Star University of Health Sciences'}, {u'count': 1, u'_id': u'Five Branches University'}]

# %% [markdown]
# # 5. Conclusion #

# %% [markdown]
# ## Summary statistics##
#
# - size of the file --> The original OSM file is **58.944542 MB** --> The JSON file is **61.66255 MB  **
#
# - number of unique users --> **534**
#
# - number of nodes and ways --> nodes: **263052**   ways: **263052**

# %% [markdown]
# ## Ideas to improve the data ##
#
# I found that the Santa Clara OSM data was fairly clean. There are 534 unique users contributing to the data. Every person has their own way of addressing street names. We can eliminate these types of human errors by keeping a data entry form which has pre-defined naming conventions.
# Also, this dataset can be better understood by visualizations using a visualization tool like Tableau. This would helps us compare different nodes in the data visually.
#
# - Cost of implementation:
# We need a team and structure that can maintain the above suggestions. Once the data entry form is set up, only minimal supervision would be required to make any changes periodically.
